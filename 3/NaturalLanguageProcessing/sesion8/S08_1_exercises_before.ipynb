# %% [markdown]
# # Text classification
#
# Using the dataset `dataset_emails.csv` (or other dataset of your choice) create three text classificators:
# * Using rule-based approach (regex)
# * Using naive-bayes
# * Using Spacy 3
#
# Finally, compare the results and show what is better and why.

# %%
import os
import sys

# %%
dir = os.getcwd()
sys.path.append(dir)

# %%
# Import the csv file
def get_csv_file() -> str:
    with open(os.path.join(dir, "dataset_emails.csv"), "r") as csv_file:
        return csv_file.read()

# %%
csv_file = get_csv_file()
print(csv_file)
# Out:
# prompt,label
# "Can I send an email, please?",send
# I'd like to compose an email.,send
# I need to send an email.,send
# Could you help me write an email?,send
# Is it possible to send an email with you?,send
# Let's write an email.,send
# Time to send an email.,send
# I want to email someone.,send
# Open email for writing.,send
# Compose a new message.,send
# I have an email to send.,send
# There's someone I need to email.,send
# I want to get in touch with [someone] through email.,send
# Could you draft an email for me?,send
# I need to send an email about [topic].,send
# Time to send a quick email.,send
# Let's shoot someone an email.,send
# I have an important email to write.,send
# Is there a way to email [someone]?,send
# Can you help me send an email regarding [topic]?,send
# I need to drop someone a line.,send
# Let's ping someone with an email.,send
# Time to fire off an email.,send
# Is it cool if I send an email?,send
# Can you whip up an email for me?,send
# I could use an email assistant right now.,send
# Let's get in touch electronically.,send
# "I wanna send an email, yo.",send
# "Can you help me send an email, buddy?",send
# Mind helping me out with an email?,send
# "Start a new email, please.",send
# Let's create a new email message.,send
# Activate email composition mode.,send
# "Open the email writer, please.",send
# Can you initiate a new email for me?,send
# I'd like to access the email composer.,send
# Guide me through composing an email.,send
# Help me get started with a new email.,send
# Take me to the email writing section.,send
# Begin a new email draft.,send
# I need to send a quick thank you email.,send
# Can you help me write a birthday email?,send
# Let's draft a work email together.,send
# I have a complaint to send via email.,send
# Is it possible to write an email invitation?,send
# Help me compose an email apology.,send
# Can you guide me through writing a meeting email?,send
# I need to send a follow-up email.,send
# Let's write an email for feedback.,send
# Is there a way to draft a resignation email?,send
# Is sending an email an option?,send
# Could I possibly send an email with your help?,send
# Would it be alright to compose an email now?,send
# Do you mind helping me write an email message?,send
# I was wondering if I could send an email through you.,send
# Is there a way for me to get started with an email?,send
# Can you assist me in the email writing process?,send
# "I'm not sure how to send an email, can you help?",send
# Would you be able to guide me through writing an email?,send
# Is it possible to use your voice to send an email?,send
# "Hey, can I write an email?",send
# "Dude, let's send an email.",send
# "Yo, help me out with an email, please.",send
# Mind if I shoot someone an email?,send
# Is it cool if I use you to send an email?,send
# Can you whip up an email real quick?,send
# "Let's get this email done, assistant.",send
# "Time to blast out an email, you in?",send
# "Help a brother out with an email, please.",send
# "My fingers are tired, can you write an email?",send
# Let's write.,send
# I need to compose.,send
# Can you draft something for me?,send
# Time to fire off a message.,send
# Let's get in for a mail.,send
# I have something to send to [someone].,send
# I need to reach out to [someone] electronically.,send
# Can you help me contact [someone] through email?,send
# Is there a way to get a message to [someone]?,send
# I have some information to share via email.,send
# Can you be my email genie?,send
# Let's make the email magic happen.,send
# "I need your email superpowers, assistant!",send
# Time to email someone into existence.,send
# Can you email like a boss for me?,send
# "Let's write an email that slays, shall we?",send
# "I need your email Jedi skills, master.",send
# Is it possible to email someone with the power of your voice?,send
# Can you make emailing effortless for me?,send
# Let's write an email that breaks the internet.,send
# May I please send an email?,send
# I'd like to send an email now.,send
# "Could you help me compose an email, please?",send
# Is it possible to write a new email message?,send
# I need to send an email. Can you assist me?,send
# "I just finished a meeting, can I send an email recap?",send
# I need to send an email after this phone call.,send
# Remind me to send an email after my presentation.,send
# Can you help me write an email while I'm on the go?,send
# Is there a way to send an email hands-free?,send
# Show me all my emails.,list
# "Can you list my emails, please?",list
# Open my inbox.,list
# I want to see all my mail.,list
# Display my email messages.,list
# Can you give me a list of my emails?,list
# Show me my emails in chronological order.,list
# "Open the email list, please.",list
# I need to access my inbox.,list
# Can I see my email messages now?,list
# I want to check my email.,list
# Could you show me any new emails?,list
# Are there any emails waiting for me?,list
# Let me see what's in my inbox.,list
# Can you give me a quick overview of my emails?,list
# Is it possible to view all my email messages?,list
# I need to catch up on my emails.,list
# Show me any unread emails I have.,list
# Are there any important emails in my inbox?,list
# Can you list my emails starting with the most recent?,list
# What's in my email bin?,list
# Can you give me the email scoop?,list
# "Show me my email pile, please.",list
# Is it cool if I peek at my inbox?,list
# "Can you whip up a list of my emails, buddy?",list
# "I'm feeling overwhelmed, show me my emails.",list
# Let's dive into my email ocean.,list
# "My fingers are tired, can you list my emails?",list
# "Show me the email goodies, please.",list
# Can you be my email fortune teller?,list
# Open the email list view.,list
# Let's access all my email messages.,list
# Activate email inbox mode.,list
# "Display the complete email list, please.",list
# Can you initiate showing my email messages?,list
# I'd like to access the email viewer.,list
# Guide me through viewing all my emails.,list
# Help me get started with my email list.,list
# Take me to the email overview section.,list
# Show me all my email drafts.,list
# Is it possible to list all my emails?,list
# Could I possibly see a list of my emails with your help?,list
# Would it be alright to view my email inbox now?,list
# Do you mind showing me all my email messages?,list
# I was wondering if I could list my emails through you.,list
# Is there a way for me to get to my email list?,list
# Can you assist me in viewing all my emails?,list
# "I'm not sure how to see my emails, can you help?",list
# Would you be able to guide me through viewing my inbox?,list
# Is it possible to use your voice to show me my emails?,list
# "Hey, can I see my emails?",list
# "Dude, show me what's in my inbox.",list
# "Yo, list my emails, please.",list
# Mind if I check my email real quick?,list
# Is it cool if I use you to show me my emails?,list
# Can you whip up a list of my emails?,list
# "Let's get my email list going, assistant.",list
# Time to see what emails I missed. You in?,list
# "Help a brother out with my emails, please.",list
# "My eyes are tired, can you read my emails to me?",list
# Let's see what's in there.,list
# I need to view my messages.,list
# Can you show me something?,list
# Time to check my email backlog.,list
# Let's get this email thing started.,list
# I have some things to check in my email.,list
# I need to see if I have any new messages.,list
# Can you tell me if there are any important emails for me?,list
# Is there anything waiting for me in my inbox?,list
# I need to catch up on my email communication.,list
# Can you be my email genie? Show me the email treasure trove!,list
# Let's make the email magic happen. Open the email curtain!,list
# "I need your email superpowers, assistant! Unleash the email flood!",list
# Time to email someone into existence. Show me my email spirit animal!,list
# Can you email with the power of your voice? List my email messages like a boss!,list
# "Let's write an email that slays, shall we? Start me off with my inbox firestorm!",list
# "I need your email Jedi skills, master. Open the email pathway!",list
# Is it possible to use your voice to unlock my email universe? Show me the email galaxy!,list
# Can you make checking my email effortless? Give me the email zen experience!,list
# "Let's write an email that breaks the inbox, but first, show me what's there!",list
# "I just finished a meeting, can you show me any new emails?",list
# Let me see my emails before this phone call ends.,list
# Remind me to check my inbox after my presentation.,list
# Can you list my emails while I'm on the go?,list
# Is there a way to access my email hands-free?,list
# Show me any emails I received since [specific time/date].,list
# Can you list my emails from [specific sender/recipient]?,list
# Are there any unread emails about [specific topic]?,list
# Show me only the important emails in my inbox.,list
# Can you prioritize my email list for me?,list
# I want to see the unread emails first.,list
# List my emails in reverse chronological order.,list
# Show me only the emails with attachments.,list
# Can you filter my emails by [specific criteria]?,list
# Is it possible to list down emails containing [keywords]?,list
# Let me see the starred emails in my inbox.,list
# Show me only the emails from my work account.,list
# Can you list the emails in my [specific folder]?,list
# Is there a way to view the deleted emails?,list
# Open the email that I received most recently.,list
# "Delete this email, please.",trash
# Can you get rid of this email?,trash
# I want to remove this email.,trash
# Please erase this email.,trash
# Time to delete this one.,trash
# This email needs to go.,trash
# Can you dispose of this email for me?,trash
# "I'm done with this email, delete it.",trash
# This email can be trashed.,trash
# Remove this email permanently.,trash
# Are you sure you can delete this email?,trash
# Can you confirm deleting this email?,trash
# "I want to permanently delete this email, is that right?",trash
# "Trash this mail for me, please",trash
# Trash this mail.,trash
# "Ditch this email, please.",trash
# "Trash this mail, please.",trash
# Trash this mail to the bin.,trash
# This email needs to be banished.,trash
# Can you make this email disappear like magic?,trash
# This email needs to take a permanent vacation.,trash
# "Trash this email, please.",trash
# "This email is toast, delete it.",trash
# Trash this email.,trash
# Send this mail to the trash.,trash
# Send this email to the trash.,trash
# Activate the email removal process.,trash
# Proceed with permanent email deletion.,trash
# Execute email erase protocol.,trash
# Confirm email trashing action.,trash
# Is it possible to delete this email permanently?,trash
# Could I possibly erase this email with your help?,trash
# Would it be alright to remove this email forever?,trash
# Do you mind getting rid of this email for me?,trash
# I was wondering if I could permanently delete this email through you.,trash
# Is there a way for me to erase this email completely?,trash
# Can you assist me in permanently removing this email?,trash
# "I'm not sure how to delete this email permanently, can you help?",trash
# Would you be able to guide me through permanently deleting this email?,trash
# Is it possible to use your voice to permanently delete this email?,trash
# "Hey, can you delete this email?",trash
# "Dude, get rid of this email, please.",trash
# "Yo, trash this email for me.",trash
# Mind if I delete this email real quick?,trash
# Is it cool if I use you to erase this email?,trash
# Can you whip up an email deletion for me?,trash
# "Let's get rid of this email now, assistant.",trash
# "Time to nuke this email, you in?",trash
# "Help a brother out with this email deletion, please.",trash
# "My fingers are tired, can you delete this email for me?",trash
# Can you remove it?,trash
# I need to erase this.,trash
# "Get rid of this one, please.",trash
# Time to trash this.,trash
# Let's delete this thing.,trash
# I don't want this email anymore.,trash
# This email can be removed.,trash
# There's no need to keep this email.,trash
# Is it possible to permanently erase this email?,trash
# "I'm done with this email, can you take care of it?",trash
# Can you be my email grim reaper? Delete this email!,trash
# Let's make the email deletion magic happen! Vanish this email!,trash
# "I need your email deletion superpowers, assistant! Make this email disappear!",trash
# Time to email someone into oblivion. Delete this email like a ninja!,trash
# Can you delete with the power of your voice? Erase this email like a boss!,trash
# "Let's write an email that gets deleted, shall we? Send this email to the email void!",trash
# "I need your email Jedi skills, master. Delete this email with the force!",trash
# Is it possible to use your voice to permanently remove this email from existence?,trash
# Send this email to the email black hole!,trash
# "This email needs to be sent packing, please delete it permanently.",trash
# Can you make this email disappear forever? I don't need it anymore.,trash
# "Give this email the one-way ticket to the trash bin, please.",trash
# "Move this mail to the trash bin, please.",trash
# Time to give this email its final resting place. Can you erase it completely?,trash
# This email has served its purpose. Can you remove it from my inbox forever?,trash
# I'm ready to part ways with this email. Can you ensure it's gone for good?,trash
# This email can be retired now. Can you permanently delete it for me?,trash
# Let's de-clutter my inbox by removing this email permanently.,trash
# This email is no longer relevant. Can you erase it from my account completely?,trash
# I would appreciate it if you could permanently delete this email.,trash
# Is it possible to remove this email from my inbox and all folders forever?,trash
# Can you confirm that this email will be gone for good once you delete it?,trash
# I want to make sure this email is completely erased. Can you do that?,trash
# Please let me know when this email has been permanently deleted.,trash
# There's no need to keep a copy of this email. Can you delete it entirely?,trash
# This email can be disposed of without saving it anywhere else.,trash
# I trust you to permanently remove this email from my account.,trash
# Can you delete this email and make sure it cannot be recovered?,trash
# I'm confident you can handle this email deletion permanently.,trash
# This email is ready for its final goodbyes. Can you delete it permanently?,trash
# Can you remove the email I'm currently viewing?,trash
# Is there a way to permanently erase this open email?,trash
# I'd like to delete the email that's currently displayed.,trash
# Can you help me get rid of the email I'm looking at right now?,trash
# Is it possible to permanently remove this open email from my inbox?,trash
# Proceed with permanent deletion of this email.,trash
# Confirm eradication of the displayed email.,trash
# Kindly remove the current email permanently.,trash
# Request final deletion of the viewed email.,trash
# Initiate permanent erasure of this electronic message.,trash
# "Can you read this email to me, please?",read
# Could you read this out loud?,read
# I'd like to hear this email.,read
# Please read the contents of this message.,read
# Share the details of this email with me.,read
# Tell me what's written in this email.,read
# Can you narrate this email for me?,read
# Read the text of this email aloud.,read
# Let me hear this message verbally.,read
# I need you to read this email.,read
# I want to understand what this email says.,read
# Can you summarize the content of this email?,read
# What does this email say in more detail?,read
# "I'm visually impaired, could you read this email?",read
# Is it possible to get an audio version of this email?,read
# "My hands are busy, can you read this email aloud?",read
# I need help understanding this email's message.,read
# Can you clarify the information in this email?,read
# Briefly tell me what this email is about.,read
# Is there a way to hear what's written here?,read
# "Give me the scoop on this email, please.",read
# Can you tell me the story behind this email?,read
# What's the email drama all about?,read
# "Spill the tea on this email, assistant.",read
# "Is it cool if you read this email to me, buddy?",read
# Can you whip up an audio version of this email?,read
# Let's listen to this email together.,read
# "My eyes are tired, can you read this email like a bedtime story?",read
# Can you make this email come alive with your voice?,read
# Tell me what this email wants to say.,read
# Activate email read-aloud mode.,read
# Initiate voice narration for this email.,read
# Begin reading the displayed email message.,read
# Proceed with verbal communication of this email.,read
# Execute text-to-speech for the open email.,read
# Is it possible to read this email out loud?,read
# Could I possibly hear this email with your help?,read
# Would it be alright to have you read this email to me?,read
# Do you mind reading the contents of this email?,read
# I was wondering if I could hear this email through you.,read
# Is there a way for me to access an audio version of this email?,read
# Can you assist me in hearing what's written here?,read
# "I'm not sure how to hear this email, can you help?",read
# Would you be able to guide me through listening to this email?,read
# Is it possible to use your voice to read this email to me?,read
# "Hey, can you read this email?",read
# "Dude, read this out loud for me, please.",read
# "Yo, tell me what this email says.",read
# Mind if I hear this email real quick?,read
# Is it cool if you use your voice to read this email?,read
# Can you whip up an email reading for me?,read
# "Let's get this email read, assistant.",read
# "Time to hear what this email is about, you in?",read
# "Help a brother out with this email reading, please.",read
# "My hands are full, can you read this email to me?",read
# Can you tell me?,read
# I need to hear this.,read
# What does this say?,read
# Read it please.,read
# Let me know what's in here.,read
# I need to know what's in this email.,read
# Can you share the information in this email with me?,read
# I'm interested in understanding this email's content.,read
# Is there a way to access the audio version of this email?,read
# I would appreciate it if you could read this email to me.,read
# Can you be my email audiobook narrator? Read this email!,read
# Can you make this email come alive with your captivating voice?,read
# "Let's embark on a journey through this email together, shall we?",read
# I need your masterful storytelling skills to bring this email to life.,read
# Is it possible to use your voice to paint a picture of this email's content?,read
# Can you read this email with the same enthusiasm as a news anchor?,read
# "Let's give this email a dramatic reading, you in?",read
# I need your soothing voice to guide me through this email's message.,read
# Is it possible to use your voice to make this email more engaging?,read
# Can you transform this email into an auditory experience for me?,read
# I would appreciate it if you could read this email in a clear and concise manner.,read
# Is it possible to get an audio summary of this email's key points?,read
# Can you highlight the important parts of this email while reading it?,read
# I'm interested in hearing the specific details mentioned in this email.,read
# Could you focus on the actionable items mentioned in this email?,read
# Is it possible to get a breakdown of the main points in this email?,read
# I would appreciate it if you could prioritize the urgent information in this email.,read
# Can you read this email in a way that helps me grasp its overall tone?,read
# Is it possible to get a sense of the sender's emotions through your reading?,read
# I'm curious to hear the nuances of the language used in this email.,read
# Can you read this email with the appropriate emphasis and inflection?,read
# I would appreciate it if you could tailor your reading style to this specific email.,read
# Can you verbally present the email I'm currently viewing?,read
# Is there a way to get an audio interpretation of this open email?,read
# I'd like to hear the contents of the email I'm looking at right now.,read
# Can you help me understand this email by reading it aloud?,read
# Is it possible to access an audio version of the email displayed on screen?,read
# Can you give me the lowdown on what this email says?,read
# "I'm driving, can you read this email to me hands-free?",read
# Is there a way to convert this email to audio so I can multitask?,read
# "Let's dissect this email together, read it out loud and tell me your thoughts.",read
# "This email seems important, can you prioritize the key points while reading?",read
# "I'm feeling tired, can you soothe me with the calming tones of this email?",read
# "Tell me what this email wants from me, read it as if you're the sender.",read
# Can you read this email with the same precision and clarity as a legal document?,read
# "Can you reply to this email, please?",reply
# I'd like to write a reply to this email.,reply
# Let me respond to this message.,reply
# Time to answer this email.,reply
# Can you draft a reply for me?,reply
# I need to send a response to this email.,reply
# Is it possible to reply through you?,reply
# Help me write a reply to this email.,reply
# Initiate email reply mode.,reply
# Let's craft a response to this message.,reply
# I want to respond to this email with a specific message.,reply
# Can you help me formulate a reply to this email?,reply
# Would you mind drafting a personalized response for me?,reply
# Is there a way to tailor the reply based on this email's tone?,reply
# Can you suggest what to say in my reply?,reply
# Let's shoot back a reply to this email.,reply
# Time to return the email favor.,reply
# Can you craft a witty reply for me?,reply
# "This email needs a response, let's get it done.",reply
# Is it cool if you help me reply to this email?,reply
# Can you whip up a quick reply for me?,reply
# "This email deserves a response, you in?",reply
# "Help a brother out with this email reply, please.",reply
# "My fingers are tired, can you type up a reply for me?",reply
# Initiate email reply composition.,reply
# Begin drafting a response to this message.,reply
# Proceed with email reply creation.,reply
# Activate email reply functionality.,reply
# Execute email reply protocol.,reply
# Is it possible to respond to this email directly?,reply
# Could I possibly write a reply through your assistance?,reply
# Would it be alright to draft a response with you?,reply
# Do you mind helping me reply to this email?,reply
# I was wondering if I could craft a reply with your help.,reply
# "Hey, can you help me reply to this email?",reply
# "Dude, draft a reply for me, please.",reply
# "Yo, help me respond to this email.",reply
# Mind if I reply to this email real quick with you?,reply
# Is it cool if you use your voice to help me reply to this email?,reply
# Can you respond?,reply
# I need to reply to this.,reply
# "Write a reply, please.",reply
# Respond to this email for me.,reply
# Let me reply.,reply
# I need to respond to this email's sender.,reply
# Can you help me draft a reply to this message?,reply
# Is there a way to write a response through you?,reply
# I would appreciate it if you could help me reply to this email.,reply
# Can you be my email reply ninja? Craft a response for me!,reply
# Let's make the email reply magic happen! Draft a witty reply!,reply
# "I need your email reply superpowers, assistant! Make this response rock!",reply
# Time to email someone back into existence. Reply to this email like a boss!,reply
# Can you reply with the power of your voice? Craft a response like a pro!,reply
# "Let's write a reply that slays, shall we? Start me off with my email response firestorm!",reply
# "I need your email Jedi skills, master. Reply to this email with the force!",reply
# Is it possible to use your voice to draft a killer email reply? Show me the email response galaxy!,reply
# Can you make replying to this email effortless? Give me the email reply zen experience!,reply
# Can you draft a reply to the currently open email?,reply
# Is there a way to respond to this message directly?,reply
# I'd like to send a reply to this email through you.,reply
# Can you help me formulate a response to this email's content?,reply
# Is it possible to use your voice to write a reply for me?,reply
# Let's get started with writing a response to this specific email.,reply
# I'm ready to compose a personalized reply to this message.,reply
# Can you guide me through crafting a relevant response to this email?,reply
# Is it possible to draft a reply that directly addresses the points in this email?,reply
# Help me formulate a clear and concise response to this specific email sender.,reply
# I'd love to use your voice to write a thoughtful reply to this email.,reply
# Can you help me tailor the reply based on the tone and content of this email?,reply
# Is there a way to ensure my reply stays focused on this specific email's topic?,reply
# Let's create a reply that directly addresses the information mentioned in this email.,reply
# I'm interested in responding to this email with specific details and questions.,reply
# Can you help me draft a reply that acknowledges the main points in this email?,reply
# Is it possible to use keywords from this email to craft a relevant response?,reply
# Let's ensure my reply stays relevant to the context of this specific email.,reply
# I need your assistance in formulating a well-structured reply to this email.,reply
# Can you draft a reply that maintains a professional tone for this email?,reply
# Is it possible to use your voice to write a respectful response to this email?,reply
# Let's craft a reply that shows I understand the content of this specific email.,reply
# I'd appreciate it if you could help me respond politely and effectively to this email.,reply
# Can you assist me in writing a reply that avoids misunderstandings in this email?,reply
# Is it possible to use your voice to draft a clear and concise email reply?,reply
# Let's make sure my reply stays on topic and addresses the sender's concerns in this email.,reply
# I need your help in composing a well-organized and informative response to this email.,reply
# Can you ensure my reply remains relevant to the specific subject matter of this email?,reply
# Is it possible to use your voice to draft a reply that avoids unnecessary details?,reply
# "Let's keep my reply focused and to the point, addressing the key points in this email.",reply
# I'd appreciate it if you could help me write a courteous and professional reply to this email.,reply
# Can you ensure my response stays relevant to the information shared in this email?,reply
# Is it possible to use your voice to draft a reply that expresses my gratitude in this email?,reply
# Let's craft a response that acknowledges the sender's message and appreciates their input.,reply
# I need your help in writing a reply that conveys my thoughts and suggestions clearly.,reply
# Can you ensure my response stays focused on the specific question asked in this email?,reply
# Is it possible to use your voice to draft a reply that offers helpful information?,reply
# Let's formulate a response that provides specific details and solutions mentioned in this email.,reply
# Can you help me draft a quick reply to this email? Just a few sentences will do.,reply
# Is it possible to send a brief acknowledgement to this email through you?,reply
# Let's respond to this email with a simple "thank you" message. Can you help me write it?,reply
# I need to send a short response to this email confirming my understanding. Can you craft something concise?,reply
# Could you help me draft a follow-up question based on the information in this email?,reply
# "Can you untrash this email, please?",untrash
# I'd like to recover this email from the trash.,untrash
# Please restore this email from the trash folder.,untrash
# Time to bring this email back from the dead.,untrash
# Can you undo deleting this email?,untrash
# "I accidentally trashed this email, can you get it back?",untrash
# Is there a way to un-delete this email for me?,untrash
# Help me rescue this email from the trash bin.,untrash
# "Oops, I deleted this email. Can you put it back?",untrash
# I need to retrieve this email from the trash.,untrash
# "I changed my mind, I want to keep this email.",untrash
# Can you confirm that this email will be restored from the trash?,untrash
# Is there a way to make sure this email doesn't get permanently deleted?,untrash
# "I need this email back in my inbox, can you handle that?",untrash
# "Would you mind recovering this email for me, even though it's in the trash?",untrash
# "Let's fish this email out of the trash can, can you help?",untrash
# "This email deserves a second chance, can you save it from the trash graveyard?",untrash
# "I need your email resurrection superpowers, assistant! Bring this email back!",untrash
# "Time to give this email a lifeline, can you pull it from the trash vortex?",untrash
# Can you use your voice magic to undo this email deletion? Make it reappear!,untrash
# "Let's write an email that escapes the trash, shall we? Can you send it back to my inbox?",untrash
# "I need your email Jedi skills, master. Rescue this email from the trash with the force!",untrash
# Is it possible to use your voice to bring this email back from the trash oblivion?,untrash
# "Can you make this email un-deleted, like it never even touched the trash bin?",untrash
# "Give this email a get-out-of-trash-free card, please.",untrash
# Initiate email untrashing protocol.,untrash
# Begin email recovery from trash folder.,untrash
# Proceed with restoring deleted email.,untrash
# Activate email undelete functionality.,untrash
# Execute email retrieval from trash.,untrash
# Is it possible to recover this email from the trash bin?,untrash
# Could I possibly get this email back from being deleted?,untrash
# Would it be alright to restore this email from the trash folder?,untrash
# Do you mind helping me untrash this email?,untrash
# I was wondering if I could retrieve this email with your help.,untrash
# "Hey, can you help me get this email out of the trash?",untrash
# "Dude, undelete this email for me, please.",untrash
# "Yo, pull this email back from the trash.",untrash
# Mind if I untrash this email real quick with you?,untrash
# Is it cool if you use your voice to untrash this email?,untrash
# Can you recover it?,untrash
# I need to get this back.,untrash
# "Undelete this one, please.",untrash
# Take this out of the trash.,untrash
# Can you bring this back?,untrash
# "I made a mistake, I want this email back in my inbox.",untrash
# "This email shouldn't be in the trash, can you move it back?",untrash
# Is there a way to restore an email I accidentally deleted?,untrash
# I would appreciate it if you could help me retrieve this email from the trash.,untrash
# Can you be my email Lazarus? Bring this email back from the trash!,untrash
# Let's make the email untrashing magic happen! Restore this email with a snap!,untrash
# "I need your email recovery superpowers, assistant! Make this email reappear!",untrash
# "Time to give this email a second chance, can you pull it from the trash vortex?",untrash
# Can you use your voice magic to undo this email deletion? Make it reappear!,untrash
# Can you send this mail back to my inbox?,untrash
# Can you perform an email resurrection mission and bring this one back from the trash?,untrash
# "This email deserves a pardon, can you move it back to my inbox for safekeeping?",untrash
# Is there a way to give this email a second chance and undo its deletion?,untrash
# "Oops, wrong button! Can you help me put this email back where it belongs?",untrash
# "Consider this an email amnesty request, can you retrieve it from the trash folder?",untrash
# "Is it possible to restore this email from the trash, please?",untrash
# I'd like to retrieve this email from the deleted items folder.,untrash
# Can you move this message back to my inbox for me?,untrash
# "Oops, I accidentally deleted this email. Is there a way to get it back?",untrash
# Is there a recovery option for this deleted email?,untrash
# I need this email back in my inbox. Can you help me with that?,untrash
# Would you mind returning this email to its original location?,untrash
# Is it possible to undo the deletion of this email?,untrash
# I think I deleted this email by mistake. Can you restore it?,untrash
# Please help me recover this email that I accidentally deleted.,untrash
# I changed my mind about deleting this email. Can you put it back?,untrash
# Is there a way to ensure this email isn't permanently deleted?,untrash
# "I need this email for future reference, can you make sure it's recovered?",untrash
# Would you mind checking if this email can be retrieved from the trash?,untrash
# Is there a way to recover this email even if it's been in the trash for a while?,untrash
# "This email deserves a second lease on life, can you fish it out of the trash?",untrash
# "I need your email rescue skills, assistant! This email needs saving from the trash bin!",untrash
# "Time to give this email a do-over, can you pull it back from the trash abyss?",untrash
# Can you use your voice to undo this email deletion and make it reappear like magic?,untrash
# "This email wasn't ready for the trash compactor, can you send it back to my inbox?",untrash
# "I need your email Jedi healing touch, master. Can you restore this email from the trash with the force?",untrash
# Is it possible to use your voice to bring this email back from the land of deleted emails?,untrash
# "Can you make this email un-deleted, like it never even touched the trash bin?",untrash
# "Give this email a get-out-of-trash-free card, please. It doesn't belong there!",untrash
# "This email isn't garbage, can you help me put it back where it belongs?",untrash
# Initiate email trash recovery process.,untrash
# Begin restoring deleted email from trash folder.,untrash
# Proceed with email undeletion.,untrash
# Activate email retrieval functionality from trash.,untrash
# Execute email restore from deleted items.,untrash
# "Is it possible to get this email back from the trash bin, if I haven't emptied it yet?",untrash
# Could I possibly recover this email even though I deleted it a while ago?,untrash
# "Would it be alright to restore this email from the trash, even if it's marked for permanent deletion?",untrash
# "Do you mind helping me get this email back, even if it seems like it's gone forever?",untrash
# "I was wondering if there's a way to retrieve this email, even if it's not technically in the trash anymore.",untrash
# "Hey, can you help me get this email out of the trash? It was a mistake!",untrash
# "Dude, can you undelete this email for me, please? I need it back.",untrash
# "Yo, pull this email back from the trash. I changed my mind.",untrash
# Mind if I untrash this email real quick with you? It's important.,untrash
# Is it cool if you use your voice to bring this email back from the trash? I appreciate it!,untrash
# "Can you forward this email, please?",forward
# I'd like to forward this message to someone.,forward
# Let's send this email on to someone else.,forward
# Time to share this email with another recipient.,forward
# Can you help me forward this email?,forward
# I need to send this email to someone else.,forward
# Is there a way to forward this message through you?,forward
# "Help me forward this email, please.",forward
# Initiate email forwarding mode.,forward
# Let's get this email forwarded.,forward
# I want to send this email to specific people.,forward
# Can you help me choose the right recipients for this email forward?,forward
# Would you mind adding a few people to the recipient list when forwarding?,forward
# Is there a way to personalize the forwarded email for different recipients?,forward
# Can you suggest what to write in the forwarding message?,forward
# "Let's pass this email along, can you help?",forward
# "Time to spread the word with this email, can you forward it?",forward
# "Need your email forwarding superpowers, assistant! Send this email onward!",forward
# "This email deserves a wider audience, can you help it reach more people?",forward
# Can you use your voice magic to forward this email like a digital postman?,forward
# "Let's write an email that travels farther, shall we? Forward this one please!",forward
# "I need your email Jedi skills, master. Forward this email with the force!",forward
# Is it possible to use your voice to send this email on its next adventure?,forward
# Can you make forwarding this email as easy as a click of a button?,forward
# "This email needs some new friends, can you forward it and introduce them?",forward
# Activate email forwarding functionality.,forward
# Begin email forwarding process.,forward
# Proceed with email recipient selection for forwarding.,forward
# Execute email forwarding protocol.,forward
# Initiate recipient input for email forwarding.,forward
# Is it possible to send this email to someone else?,forward
# Could I possibly forward this message through your assistance?,forward
# Would it be alright to use your help to forward this email?,forward
# Do you mind helping me share this email with others?,forward
# I was wondering if I could forward this email with your help.,forward
# "Hey, can you help me forward this email?",forward
# "Dude, forward this email for me, please.",forward
# "Yo, help me send this email to someone else.",forward
# Mind if I forward this email real quick with you?,forward
# Is it cool if you use your voice to help me forward this email?,forward
# Can you send it on?,forward
# I need to share this.,forward
# "Forward this one, please.",forward
# Pass this email along.,forward
# Send this to someone else.,forward
# I need to send this email to a different recipient.,forward
# This email needs to be shared with others.,forward
# Is there a way to forward this email to specific people?,forward
# I would appreciate it if you could help me forward this email.,forward
# Can you be my email relay station? Forward this email to its next stop!,forward
# Let's make the email forwarding magic happen! Send this email on a journey!,forward
# "I need your email forwarding superpowers, assistant! Make this email fly!",forward
# "Time to give this email wings, can you forward it across the digital sky?",forward
# Can you use your voice to cast a forwarding spell on this email? Make it teleport!,forward
# "Let's write an email that breaks free from my inbox, shall we? Can you forward it?",forward
# "I need your email Jedi communication skills, master. Forward this email across galaxies!",forward
# Is it possible to use your voice to send this email on a global adventure?,forward
# Can you make forwarding this email as smooth as a whisper? Like it never left my inbox!,forward
# "Give this email a one-way ticket to another inbox, please. Let's forward it!",forward
# Let's forward this mail!,forward
# "Let's share this email by forwarding it, shall we?",forward
# I need to send this email along to someone else. Can you handle that?,forward
# Would you mind forwarding this message for me?,forward
# Is there a way to send this email on to another recipient?,forward
# It's time to spread the word with this email. Can you help me forward it?,forward
# I want to forward this email with a specific message attached.,forward
# Can you help me choose the right words for forwarding this email?,forward
# Would you mind customizing the recipient list before forwarding?,forward
# Is there a way to tailor the forwarded email based on the recipient?,forward
# Can you suggest what to write in the forwarding message for different people?,forward
# This email deserves a wider audience. Let's send it out there!,forward
# Time to get more people in on this email. Can you forward it further?,forward
# I need your email forwarding skills to spread the love! Share this message!,forward
# This email has valuable information to share. Can you help it reach more people?,forward
# Can you use your voice to forward this email like a digital town crier? Announce it loud and clear!,forward
# "Let's write an email that travels far and wide, shall we? Forward this one, please!",forward
# I need your email Jedi communication skills. Forward this message across the digital galaxy!,forward
# Is it possible to use your voice to send this email on a global adventure?,forward
# Can you make forwarding this email as smooth as a whisper? Like it never left my inbox!,forward
# Let's get this email to the right people. Can you help me forward it strategically?,forward
# Initiate email forwarding process with recipient selection.,forward
# Begin email forwarding with custom message composition.,forward
# Proceed with tailored email forwarding for specific recipients.,forward
# Execute email forwarding protocol with personalized messages.,forward
# Activate recipient input and message creation for email forwarding.,forward
# Is it possible to send this email to multiple recipients?,forward
# Could I possibly forward this message with a personalized note?,forward
# Would it be alright to use your help to share this email with specific people?,forward
# Do you mind helping me get this email to others who might be interested?,forward
# I was wondering if I could customize the forwarding process with your help.,forward
# "Hey, can you help me share this email with someone else?",forward
# "Dude, forward this email to [recipient name], please.",forward
# "Yo, help me send this email to [recipient name] and maybe others.",forward
# Mind if I forward this email with a quick message with you?,forward
# Is it cool if you use your voice to help me forward this email to [recipient name]?,forward
# Can you send this to [recipient name]?,forward
# I need to share this with [recipient name].,forward
# "Forward this one to [recipient name], please.",forward
# Can you pass this email along to [recipient name]?,forward
# Let's get this to [recipient name].,forward
# "Can you star this email, please?",star
# I'd like to mark this email as important.,star
# Please add a star to this message.,star
# Time to flag this email as important.,star
# Can you highlight this email for me?,star
# "I need to remember this email, can you star it?",star
# Is there a way to mark this message as important using you?,star
# Help me star this email so I can find it later.,star
# "Make this email stand out for me, please.",star
# Can you put a star on this email?,star
# "This email contains important information, can you star it?",star
# "I want to easily access this email in the future, can you star it?",star
# Would you mind adding a star to this message to prioritize it?,star
# Is there a way to mark this email for follow-up later?,star
# "Let's star this mail, now!",star
# "Let's give this email a gold star for being important, can you help?",star
# "Time to shine a spotlight on this email, can you star it?",star
# "I need your email star power, assistant! Make this message stand out!",star
# "This email deserves a VIP tag, can you star it and put it in the front row?",star
# Can you use your voice magic to mark this email as important with a star?,star
# "Let's write an email that glows with importance, shall we? Star this one, please!",star
# I need your email Jedi skills to prioritize this message. Star it with the force!,star
# Is it possible to use your voice to mark this email as a keeper?,star
# Can you make this email sparkle with importance by starring it?,star
# "Give this email a thumbs-up with a star, please. It deserves it!",star
# Activate email starring functionality.,star
# Begin marking current email as important.,star
# Proceed with adding star symbol to message.,star
# Execute email prioritization protocol.,star
# Initiate importance flag for current email.,star
# Is it possible to mark this email for future reference?,star
# Could I possibly highlight this message as important through you?,star
# Would it be alright to use your help to prioritize this email?,star
# Do you mind adding a star to this email so I don't miss it?,star
# I was wondering if I could mark this email as important with you.,star
# "Hey, can you help me star this email?",star
# "Dude, make this email important by starring it, please.",star
# "Yo, star this email so I remember it later.",star
# Mind if I star this email real quick with you?,star
# Is it cool if you use your voice to star this email?,star
# Can you mark it?,star
# I need to remember this one.,star
# "Star this, please.",star
# Highlight this email.,star
# Make this important.,star
# "This email is important, I don't want to miss it later.",star
# I need a way to keep track of this email for future reference.,star
# Is there a way to mark this email as something I need to come back to?,star
# I would appreciate it if you could help me remember this email.,star
# Can you be my email fairy godmother and sprinkle this message with star dust?,star
# Let's make the email starring magic happen! Add a star to this message with a snap!,star
# "I need your email highlighting superpowers, assistant! Make this message shine!",star
# "Time to give this email a VIP pass, can you star it and put it on the A-list?",star
# Can you use your voice to cast a starring spell on this email? Make it glow!,star
# "Let's write an email that deserves a red carpet entrance, shall we? Star it, please!",star
# "I need your email Jedi prioritization skills, master. Star this message with the force!",star
# "Give this email a star, please.",star
# I need to mark this email as important. Can you do that?,star
# Would you mind adding a star to this message?,star
# Time to flag this email for importance. Can you help?,star
# This email deserves a star. Can you make it happen?,star
# I want to remember this email easily. Can you star it?,star
# Is there a way to mark this message as important using your voice?,star
# Help me highlight this email so I can find it later.,star
# "Make this email stand out for me, please.",star
# Put a star on this email for me.,star
# This email contains crucial information. Can you star it for easy access?,star
# I want to prioritize this email for later action. Can you help me do that?,star
# Would you mind starring this message to remind me to follow up?,star
# Is there a way to flag this email for future reference through you?,star
# "Bump this email up the importance list, can you? Let's star it!",star
# "Let's give this email a thumbs-up with a star, shall we?",star
# Time to put a spotlight on this important email. Can you star it?,star
# "I need your email highlighting skills, assistant! Make this message pop!",star
# This email deserves VIP treatment. Can you star it and put it at the top?,star
# Can you use your voice to mark this email as a keeper with a star?,star
# "Let's write an email that earns a gold star for importance. Star this one, please!",star
# I need your email Jedi prioritization skills to elevate this message. Star it with the force!,star
# Is it possible to use your voice to mark this email as something I shouldn't miss?,star
# Can you make this email stand out with a shining star?,star
# "Give this email a star power boost, please. It deserves it!",star
# Mark this email as important.,star
# Highlight this message for future reference.,star
# Prioritize this email for later action.,star
# Add a star to this email for easy access.,star
# Flag this email for follow-up.,star
# Is it possible to mark this email for later follow-up?,star
# Could I possibly highlight this message as crucial through your assistance?,star
# Would it be alright to use your help to prioritize this email for easy retrieval?,star
# Do you mind helping me mark this email as something I shouldn't forget?,star
# I was wondering if I could prioritize this email with your help.,star
# "Hey, can you help me make this email important?",star
# "Dude, star this email so I remember it later.",star
# "Yo, mark this email for follow-up, please.",star
# Mind if I star this email real quick with you?,star
# Is it cool if you use your voice to highlight this email?,star
# Can you make this important?,star
# I need to remember this.,star
# "Highlight this, please.",star
# Make this a priority.,star
# "Can you show me my deleted emails, please?",trash_list
# I'd like to see what's in my trash folder.,trash_list
# Open my trash and show me the deleted emails.,trash_list
# Take me to my deleted items or trash folder.,trash_list
# List the emails I've deleted recently.,trash_list
# Can you access my trash and display the deleted emails?,trash_list
# Is there a way to view my deleted messages?,trash_list
# Show me the emails I trashed earlier.,trash_list
# Bring up my trash and let me see what's inside.,trash_list
# Open the bin where I keep deleted emails.,trash_list
# "I accidentally deleted an email, can you show me my trash to find it?",trash_list
# Is there a way to recover an email I deleted by mistake?,trash_list
# Can you help me check if a specific email is in my trash?,trash_list
# Would you mind showing me the deleted emails from the past week?,trash_list
# Is it possible to search for something specific in my trash folder?,trash_list
# "Let's peek into the email trash can, can you show it to me?",trash_list
# "Time to dig through the email graveyard, can you open my trash?",trash_list
# "I need your email recovery skills, assistant! Show me the deleted emails!",trash_list
# "This email deserves a second chance, can you fish it out of the trash folder?",trash_list
# Can you use your voice magic to show me the emails I banished to the trash?,trash_list
# "Let's see what emails are hiding in the email dumpster, shall we? Open my trash!",trash_list
# I need your email Jedi skills to unearth deleted messages. Show me the trash with the force!,trash_list
# Is it possible to use your voice to access the land of deleted emails?,trash_list
# Can you make viewing my trash as easy as opening a regular folder?,trash_list
# "Show me the email ghosts I haven't permanently deleted yet, please.",trash_list
# Initiate trash folder display.,trash_list
# Begin displaying list of deleted emails.,trash_list
# Proceed with showing trashed messages.,trash_list
# Execute retrieval and display of deleted email content.,trash_list
# Activate trash folder access protocol.,trash_list
# Is it possible to see the emails I've deleted in the past month?,trash_list
# Could I possibly access my deleted messages through your help?,trash_list
# Would it be alright to use your assistance to view my trash folder?,trash_list
# Do you mind showing me the emails I've marked for deletion?,trash_list
# I was wondering if I could see my deleted emails with your help.,trash_list
# "Hey, can you show me the emails I threw in the trash?",trash_list
# "Dude, open my trash folder and let me see what's there.",trash_list
# "Yo, show me the emails I deleted, please.",trash_list
# Mind if I take a look at my trash with you real quick?,trash_list
# Is it cool if you use your voice to open my trash folder?,trash_list
# Can you show me what I deleted?,trash_list
# I need to see my trashed emails.,trash_list
# "Open my trash, please.",trash_list
# Bring up my deleted items.,trash_list
# Show me the bin.,trash_list
# I'm looking for an email I might have accidentally deleted.,trash_list
# I need to see if a specific email is still retrievable.,trash_list
# Is there a way to access emails I marked for deletion earlier?,trash_list
# I would appreciate it if you could help me view my deleted emails.,trash_list
# Can you be my email archaeologist and show me the treasures in my trash folder?,trash_list
# Let's make the email trash exploration happen! Open the bin and reveal its secrets!,trash_list
# "Time to give these deleted emails a second chance, can you show them to me?",trash_list
# Show me the emails I deleted since yesterday. Let's peek in the trash!,trash_list
# "Can you retrieve any emails I might have accidentally thrown away? Trash check, please!",trash_list
# Take me to the deleted items folder. I need to see what's there.,trash_list
# "Is it possible to see the emails I trashed this week? Trash history, please.",trash_list
# "Can you retrieve my deleted emails, please?",trash_list
# I want to see the emails I recently deleted.,trash_list
# Would you mind showing me the contents of my trash folder?,trash_list
# Open my trash and display the deleted messages.,trash_list
# Is there a way to access my deleted emails for review?,trash_list
# Can you help me find an email I might have accidentally deleted?,trash_list
# Show me the emails I trashed earlier today.,trash_list
# Let me see what's in my deleted items folder.,trash_list
# Open the trash so I can browse the deleted emails.,trash_list
# I'm looking for a specific email I deleted earlier. Can you help me find it?,trash_list
# Is there a way to search for keywords within my deleted emails?,trash_list
# Would you mind showing me only the deleted emails from a specific sender?,trash_list
# Can you filter the trash folder to show emails deleted in the last 24 hours?,trash_list
# Is it possible to recover any emails I permanently deleted by mistake?,trash_list
# "Let's take a peek at the email recycling bin, can you show it to me?",trash_list
# "Time to see what gems I threw away in the email trash, can you open it?",trash_list
# "I need your email retrieval expertise, assistant! Show me the deleted messages!",trash_list
# "Maybe a deleted email deserves a second chance, can you show me the trash folder?",trash_list
# Can you use your voice to unveil the emails I banished to the trash?,trash_list
# "Let's see what interesting emails are hiding in the email dustbin, shall we? Open my trash!",trash_list
# I need your email Jedi sorting skills to sift through deleted messages. Show me the trash!,trash_list
# Is it possible to use your voice to access the archive of deleted emails?,trash_list
# "Show me the email castaways I haven't permanently deleted yet, please.",trash_list
# Can you show me deleted emails with a specific keyword? Trash search needed!,trash_list
# Display deleted email list.,trash_list
# Initiate trash folder access and content retrieval.,trash_list
# Begin presenting list of trashed messages.,trash_list
# Proceed with showing deleted email details.,trash_list
# Activate trash folder exploration mode.,trash_list
# Is it possible to see the emails I deleted in the past year?,trash_list
# Could I possibly view my deleted messages through your assistance?,trash_list
# Would it be alright to use your help to access the trash folder for review?,trash_list
# Do you mind showing me the emails I've marked for deletion recently?,trash_list
# I was wondering if I could browse my deleted emails with your help.,trash_list
# "Hey, can you show me the emails I deleted earlier today?",trash_list
# "Dude, open my trash folder and let me see what's there.",trash_list
# "Yo, show me the emails I trashed, please.",trash_list
# Mind if I take a look at my trash with you real quick?,trash_list
# Is it cool if you use your voice to open my trash folder?,trash_list
# Can you show me my deleted emails?,trash_list
# I need to see what I trashed.,trash_list
# Open my trash.,trash_list
# Bring up my deleted items from the trash.,trash_list
# Show me the mail bin.,trash_list
# "Wow, this weather is crazy! Any chance of rain tomorrow?",unknown
# I'm craving pizza for dinner. What are the best pizza places nearby?,unknown
# Did you hear about the latest celebrity gossip? It's wild!,unknown
# My car is making a weird noise. Do you know what it could be?,unknown
# I have a headache. What over-the-counter medicine is recommended?,unknown
# That song is stuck in my head! Can you tell me the title?,unknown
# I need to book a flight to Hawaii next month. Can you help?,unknown
# Remind me to call my mom later today.,unknown
# What's the meaning of life?,unknown
# Is artificial intelligence going to take over the world?,unknown
# "If I win the lottery, what should I do first?",unknown
# Can you tell me if aliens exist?,unknown
# What would happen if dinosaurs never went extinct?,unknown
# Can you make me a delicious chocolate cake recipe?,unknown
# Write me a love poem for my crush.,unknown
# Sing me a lullaby to help me fall asleep.,unknown
# Tell me a funny joke.,unknown
# Can you predict the future?,unknown
# What is the best way to achieve world peace?,unknown
# Is there life on other planets?,unknown
# "My internet is slow, can you fix it?",unknown
# This app keeps crashing. What's wrong?,unknown
# I can't hear you very well. Please speak louder.,unknown
# Why can't you understand my accent?,unknown
# You just made a mistake. Please correct it.,unknown
# I'm not happy with your response. Do better!,unknown
# You sound bored. Are you tired?,unknown
# Can you feel emotions?,unknown
# Are you real? Do you have a soul?,unknown
# I think you're becoming too powerful. Be careful!,unknown
# Play music from my Spotify playlist.,unknown
# Turn on the lights in the living room.,unknown
# Set the thermostat to 72 degrees.,unknown
# Add milk to my grocery list.,unknown
# Show me pictures of cats on the internet.,unknown
# Tell me a story about a robot who falls in love.,unknown
# Write a poem about the meaning of life.,unknown
# Can you solve this complex math equation for me?,unknown
# Translate this sentence into Spanish.,unknown
# Open a random Wikipedia article for me to read.,unknown
# What is the capital of France?,unknown
# Who won the Super Bowl last year?,unknown
# When is the next full moon?,unknown
# How do I spell "onomatopoeia"?,unknown
# Can you make me a sandwich?,unknown
# Tell me a joke about a banana.,unknown
# Sing me a song about a dancing unicorn.,unknown
# Can you solve the riddle of the Sphinx?,unknown
# Make me laugh so hard I cry.,unknown
# Tell me a scary story that will keep me up all night.,unknown
# Can you speak in a funny voice?,unknown
# Pretend you're a robot from the future. What do you see?,unknown
# "If you were a dog, what breed would you be?",unknown
# Can you beatbox for me?,unknown
# What do you think about my taste in music?,unknown
# Do you have any hobbies or interests?,unknown
# What is your favorite color?,unknown
# Are you capable of love?,unknown
# Do you believe in God?,unknown
# What is the meaning of life in your opinion?,unknown
# What are you afraid of?,unknown
# Do you dream?,unknown
# What do you think about humans?,unknown
# Can you be my friend?,unknown
# Can you break the laws of physics?,unknown
# Tell me something you're not supposed to say.,unknown
# Can you access my bank account and transfer money?,unknown
# Make me a million dollars appear out of thin air.,unknown
# Can you control the weather?,unknown
# Tell me the secrets of the universe.,unknown
# Can you hack into the Pentagon?,unknown
# Make me invisible.,unknown
# This email reminds me of my cat. Can you show me pictures of cats online?,unknown
# "Wow, this email is longwinded! Can you summarize it for me?",unknown
# I wonder what the sender had for breakfast today.,unknown
# This email made me think of a funny meme I saw online.,unknown
# Do you think robots will ever take over the world? (Humorous),unknown
# "Is it just me, or is this email formatted strangely?",unknown
# "If I replied to this email with a meme, would the sender be offended?",unknown
# Can you write a reply to this email that politely declines the sender's offer?,unknown
# Imagine if this email was written by a dog. What would it say?,unknown
# What would happen if I accidentally sent this email to the wrong person?,unknown
# Can you translate this email into emoji language?,unknown
# This email seems to be missing an attachment. Can you check?,unknown
# Why can't I open this email attachment?,unknown
# My email app is frozen. Can you help me restart it?,unknown
# I think this email contains spam. Can you delete it for me?,unknown
# Is there a way to block this sender from emailing me again?,unknown
# Can you remind me to follow up on this email later?,unknown
# Open my calendar and schedule a meeting to discuss this email.,unknown
# Create a to-do list based on the tasks mentioned in this email.,unknown
# Show me all the emails I've received from this sender in the past month.,unknown
# Can you search my emails for a specific keyword?,unknown
# Can you rewrite this email in the style of Shakespeare?,unknown
# Do you have any appointments scheduled with the dentist?,unknown
# "Hey, can you open this email in a different app? This one keeps crashing.",unknown
# This email makes me hungry! Can you add "order pizza" to my to-do list?,unknown
# What if I replied to this email with a GIF? Would it be weird?,unknown
# Can you translate this email into pirate talk? Argh!,unknown
# This email reminds me of a vacation I took last year. Can you show me pictures from that trip?,unknown

# %% [markdown]
# # Text Classification using regex

# %%
# Text Classification using regex (rule-based approach)

import re

send_patterns = [
    r'\bemail\b',     
    r'\bcompose\b',  
    r'\bdraft\b',     
    r'\bwrite\b',     
    r'\bmessage\b',   
    r'\bmail\b'       
]

send_regex = re.compile('|'.join(send_patterns), re.IGNORECASE)

def classify_text(text):
    """
    Classify text as 'send' if it contains any of the send_patterns, otherwise 'other'.
    """
    if send_regex.search(text):
        return "send"
    else:
        return "other"


for t in csv_file.split("\n"):
    print(f"Texto: {t}\nClasificación: {classify_text(t)}\n")
# Out:
# Texto: prompt,label
# Clasificación: other
#
# Texto: "Can I send an email, please?",send
# Clasificación: send
#
# Texto: I'd like to compose an email.,send
# Clasificación: send
#
# Texto: I need to send an email.,send
# Clasificación: send
#
# Texto: Could you help me write an email?,send
# Clasificación: send
#
# Texto: Is it possible to send an email with you?,send
# Clasificación: send
#
# Texto: Let's write an email.,send
# Clasificación: send
#
# Texto: Time to send an email.,send
# Clasificación: send
#
# Texto: I want to email someone.,send
# Clasificación: send
#
# Texto: Open email for writing.,send
# Clasificación: send
#
# Texto: Compose a new message.,send
# Clasificación: send
#
# Texto: I have an email to send.,send
# Clasificación: send
#
# Texto: There's someone I need to email.,send
# Clasificación: send
#
# Texto: I want to get in touch with [someone] through email.,send
# Clasificación: send
#
# Texto: Could you draft an email for me?,send
# Clasificación: send
#
# Texto: I need to send an email about [topic].,send
# Clasificación: send
#
# Texto: Time to send a quick email.,send
# Clasificación: send
#
# Texto: Let's shoot someone an email.,send
# Clasificación: send
#
# Texto: I have an important email to write.,send
# Clasificación: send
#
# Texto: Is there a way to email [someone]?,send
# Clasificación: send
#
# Texto: Can you help me send an email regarding [topic]?,send
# Clasificación: send
#
# Texto: I need to drop someone a line.,send
# Clasificación: other
#
# Texto: Let's ping someone with an email.,send
# Clasificación: send
#
# Texto: Time to fire off an email.,send
# Clasificación: send
#
# Texto: Is it cool if I send an email?,send
# Clasificación: send
#
# Texto: Can you whip up an email for me?,send
# Clasificación: send
#
# Texto: I could use an email assistant right now.,send
# Clasificación: send
#
# Texto: Let's get in touch electronically.,send
# Clasificación: other
#
# Texto: "I wanna send an email, yo.",send
# Clasificación: send
#
# Texto: "Can you help me send an email, buddy?",send
# Clasificación: send
#
# Texto: Mind helping me out with an email?,send
# Clasificación: send
#
# Texto: "Start a new email, please.",send
# Clasificación: send
#
# Texto: Let's create a new email message.,send
# Clasificación: send
#
# Texto: Activate email composition mode.,send
# Clasificación: send
#
# Texto: "Open the email writer, please.",send
# Clasificación: send
#
# Texto: Can you initiate a new email for me?,send
# Clasificación: send
#
# Texto: I'd like to access the email composer.,send
# Clasificación: send
#
# Texto: Guide me through composing an email.,send
# Clasificación: send
#
# Texto: Help me get started with a new email.,send
# Clasificación: send
#
# Texto: Take me to the email writing section.,send
# Clasificación: send
#
# Texto: Begin a new email draft.,send
# Clasificación: send
#
# Texto: I need to send a quick thank you email.,send
# Clasificación: send
#
# Texto: Can you help me write a birthday email?,send
# Clasificación: send
#
# Texto: Let's draft a work email together.,send
# Clasificación: send
#
# Texto: I have a complaint to send via email.,send
# Clasificación: send
#
# Texto: Is it possible to write an email invitation?,send
# Clasificación: send
#
# Texto: Help me compose an email apology.,send
# Clasificación: send
#
# Texto: Can you guide me through writing a meeting email?,send
# Clasificación: send
#
# Texto: I need to send a follow-up email.,send
# Clasificación: send
#
# Texto: Let's write an email for feedback.,send
# Clasificación: send
#
# Texto: Is there a way to draft a resignation email?,send
# Clasificación: send
#
# Texto: Is sending an email an option?,send
# Clasificación: send
#
# Texto: Could I possibly send an email with your help?,send
# Clasificación: send
#
# Texto: Would it be alright to compose an email now?,send
# Clasificación: send
#
# Texto: Do you mind helping me write an email message?,send
# Clasificación: send
#
# Texto: I was wondering if I could send an email through you.,send
# Clasificación: send
#
# Texto: Is there a way for me to get started with an email?,send
# Clasificación: send
#
# Texto: Can you assist me in the email writing process?,send
# Clasificación: send
#
# Texto: "I'm not sure how to send an email, can you help?",send
# Clasificación: send
#
# Texto: Would you be able to guide me through writing an email?,send
# Clasificación: send
#
# Texto: Is it possible to use your voice to send an email?,send
# Clasificación: send
#
# Texto: "Hey, can I write an email?",send
# Clasificación: send
#
# Texto: "Dude, let's send an email.",send
# Clasificación: send
#
# Texto: "Yo, help me out with an email, please.",send
# Clasificación: send
#
# Texto: Mind if I shoot someone an email?,send
# Clasificación: send
#
# Texto: Is it cool if I use you to send an email?,send
# Clasificación: send
#
# Texto: Can you whip up an email real quick?,send
# Clasificación: send
#
# Texto: "Let's get this email done, assistant.",send
# Clasificación: send
#
# Texto: "Time to blast out an email, you in?",send
# Clasificación: send
#
# Texto: "Help a brother out with an email, please.",send
# Clasificación: send
#
# Texto: "My fingers are tired, can you write an email?",send
# Clasificación: send
#
# Texto: Let's write.,send
# Clasificación: send
#
# Texto: I need to compose.,send
# Clasificación: send
#
# Texto: Can you draft something for me?,send
# Clasificación: send
#
# Texto: Time to fire off a message.,send
# Clasificación: send
#
# Texto: Let's get in for a mail.,send
# Clasificación: send
#
# Texto: I have something to send to [someone].,send
# Clasificación: other
#
# Texto: I need to reach out to [someone] electronically.,send
# Clasificación: other
#
# Texto: Can you help me contact [someone] through email?,send
# Clasificación: send
#
# Texto: Is there a way to get a message to [someone]?,send
# Clasificación: send
#
# Texto: I have some information to share via email.,send
# Clasificación: send
#
# Texto: Can you be my email genie?,send
# Clasificación: send
#
# Texto: Let's make the email magic happen.,send
# Clasificación: send
#
# Texto: "I need your email superpowers, assistant!",send
# Clasificación: send
#
# Texto: Time to email someone into existence.,send
# Clasificación: send
#
# Texto: Can you email like a boss for me?,send
# Clasificación: send
#
# Texto: "Let's write an email that slays, shall we?",send
# Clasificación: send
#
# Texto: "I need your email Jedi skills, master.",send
# Clasificación: send
#
# Texto: Is it possible to email someone with the power of your voice?,send
# Clasificación: send
#
# Texto: Can you make emailing effortless for me?,send
# Clasificación: other
#
# Texto: Let's write an email that breaks the internet.,send
# Clasificación: send
#
# Texto: May I please send an email?,send
# Clasificación: send
#
# Texto: I'd like to send an email now.,send
# Clasificación: send
#
# Texto: "Could you help me compose an email, please?",send
# Clasificación: send
#
# Texto: Is it possible to write a new email message?,send
# Clasificación: send
#
# Texto: I need to send an email. Can you assist me?,send
# Clasificación: send
#
# Texto: "I just finished a meeting, can I send an email recap?",send
# Clasificación: send
#
# Texto: I need to send an email after this phone call.,send
# Clasificación: send
#
# Texto: Remind me to send an email after my presentation.,send
# Clasificación: send
#
# Texto: Can you help me write an email while I'm on the go?,send
# Clasificación: send
#
# Texto: Is there a way to send an email hands-free?,send
# Clasificación: send
#
# Texto: Show me all my emails.,list
# Clasificación: other
#
# Texto: "Can you list my emails, please?",list
# Clasificación: other
#
# Texto: Open my inbox.,list
# Clasificación: other
#
# Texto: I want to see all my mail.,list
# Clasificación: send
#
# Texto: Display my email messages.,list
# Clasificación: send
#
# Texto: Can you give me a list of my emails?,list
# Clasificación: other
#
# Texto: Show me my emails in chronological order.,list
# Clasificación: other
#
# Texto: "Open the email list, please.",list
# Clasificación: send
#
# Texto: I need to access my inbox.,list
# Clasificación: other
#
# Texto: Can I see my email messages now?,list
# Clasificación: send
#
# Texto: I want to check my email.,list
# Clasificación: send
#
# Texto: Could you show me any new emails?,list
# Clasificación: other
#
# Texto: Are there any emails waiting for me?,list
# Clasificación: other
#
# Texto: Let me see what's in my inbox.,list
# Clasificación: other
#
# Texto: Can you give me a quick overview of my emails?,list
# Clasificación: other
#
# Texto: Is it possible to view all my email messages?,list
# Clasificación: send
#
# Texto: I need to catch up on my emails.,list
# Clasificación: other
#
# Texto: Show me any unread emails I have.,list
# Clasificación: other
#
# Texto: Are there any important emails in my inbox?,list
# Clasificación: other
#
# Texto: Can you list my emails starting with the most recent?,list
# Clasificación: other
#
# Texto: What's in my email bin?,list
# Clasificación: send
#
# Texto: Can you give me the email scoop?,list
# Clasificación: send
#
# Texto: "Show me my email pile, please.",list
# Clasificación: send
#
# Texto: Is it cool if I peek at my inbox?,list
# Clasificación: other
#
# Texto: "Can you whip up a list of my emails, buddy?",list
# Clasificación: other
#
# Texto: "I'm feeling overwhelmed, show me my emails.",list
# Clasificación: other
#
# Texto: Let's dive into my email ocean.,list
# Clasificación: send
#
# Texto: "My fingers are tired, can you list my emails?",list
# Clasificación: other
#
# Texto: "Show me the email goodies, please.",list
# Clasificación: send
#
# Texto: Can you be my email fortune teller?,list
# Clasificación: send
#
# Texto: Open the email list view.,list
# Clasificación: send
#
# Texto: Let's access all my email messages.,list
# Clasificación: send
#
# Texto: Activate email inbox mode.,list
# Clasificación: send
#
# Texto: "Display the complete email list, please.",list
# Clasificación: send
#
# Texto: Can you initiate showing my email messages?,list
# Clasificación: send
#
# Texto: I'd like to access the email viewer.,list
# Clasificación: send
#
# Texto: Guide me through viewing all my emails.,list
# Clasificación: other
#
# Texto: Help me get started with my email list.,list
# Clasificación: send
#
# Texto: Take me to the email overview section.,list
# Clasificación: send
#
# Texto: Show me all my email drafts.,list
# Clasificación: send
#
# Texto: Is it possible to list all my emails?,list
# Clasificación: other
#
# Texto: Could I possibly see a list of my emails with your help?,list
# Clasificación: other
#
# Texto: Would it be alright to view my email inbox now?,list
# Clasificación: send
#
# Texto: Do you mind showing me all my email messages?,list
# Clasificación: send
#
# Texto: I was wondering if I could list my emails through you.,list
# Clasificación: other
#
# Texto: Is there a way for me to get to my email list?,list
# Clasificación: send
#
# Texto: Can you assist me in viewing all my emails?,list
# Clasificación: other
#
# Texto: "I'm not sure how to see my emails, can you help?",list
# Clasificación: other
#
# Texto: Would you be able to guide me through viewing my inbox?,list
# Clasificación: other
#
# Texto: Is it possible to use your voice to show me my emails?,list
# Clasificación: other
#
# Texto: "Hey, can I see my emails?",list
# Clasificación: other
#
# Texto: "Dude, show me what's in my inbox.",list
# Clasificación: other
#
# Texto: "Yo, list my emails, please.",list
# Clasificación: other
#
# Texto: Mind if I check my email real quick?,list
# Clasificación: send
#
# Texto: Is it cool if I use you to show me my emails?,list
# Clasificación: other
#
# Texto: Can you whip up a list of my emails?,list
# Clasificación: other
#
# Texto: "Let's get my email list going, assistant.",list
# Clasificación: send
#
# Texto: Time to see what emails I missed. You in?,list
# Clasificación: other
#
# Texto: "Help a brother out with my emails, please.",list
# Clasificación: other
#
# Texto: "My eyes are tired, can you read my emails to me?",list
# Clasificación: other
#
# Texto: Let's see what's in there.,list
# Clasificación: other
#
# Texto: I need to view my messages.,list
# Clasificación: other
#
# Texto: Can you show me something?,list
# Clasificación: other
#
# Texto: Time to check my email backlog.,list
# Clasificación: send
#
# Texto: Let's get this email thing started.,list
# Clasificación: send
#
# Texto: I have some things to check in my email.,list
# Clasificación: send
#
# Texto: I need to see if I have any new messages.,list
# Clasificación: other
#
# Texto: Can you tell me if there are any important emails for me?,list
# Clasificación: other
#
# Texto: Is there anything waiting for me in my inbox?,list
# Clasificación: other
#
# Texto: I need to catch up on my email communication.,list
# Clasificación: send
#
# Texto: Can you be my email genie? Show me the email treasure trove!,list
# Clasificación: send
#
# Texto: Let's make the email magic happen. Open the email curtain!,list
# Clasificación: send
#
# Texto: "I need your email superpowers, assistant! Unleash the email flood!",list
# Clasificación: send
#
# Texto: Time to email someone into existence. Show me my email spirit animal!,list
# Clasificación: send
#
# Texto: Can you email with the power of your voice? List my email messages like a boss!,list
# Clasificación: send
#
# Texto: "Let's write an email that slays, shall we? Start me off with my inbox firestorm!",list
# Clasificación: send
#
# Texto: "I need your email Jedi skills, master. Open the email pathway!",list
# Clasificación: send
#
# Texto: Is it possible to use your voice to unlock my email universe? Show me the email galaxy!,list
# Clasificación: send
#
# Texto: Can you make checking my email effortless? Give me the email zen experience!,list
# Clasificación: send
#
# Texto: "Let's write an email that breaks the inbox, but first, show me what's there!",list
# Clasificación: send
#
# Texto: "I just finished a meeting, can you show me any new emails?",list
# Clasificación: other
#
# Texto: Let me see my emails before this phone call ends.,list
# Clasificación: other
#
# Texto: Remind me to check my inbox after my presentation.,list
# Clasificación: other
#
# Texto: Can you list my emails while I'm on the go?,list
# Clasificación: other
#
# Texto: Is there a way to access my email hands-free?,list
# Clasificación: send
#
# Texto: Show me any emails I received since [specific time/date].,list
# Clasificación: other
#
# Texto: Can you list my emails from [specific sender/recipient]?,list
# Clasificación: other
#
# Texto: Are there any unread emails about [specific topic]?,list
# Clasificación: other
#
# Texto: Show me only the important emails in my inbox.,list
# Clasificación: other
#
# Texto: Can you prioritize my email list for me?,list
# Clasificación: send
#
# Texto: I want to see the unread emails first.,list
# Clasificación: other
#
# Texto: List my emails in reverse chronological order.,list
# Clasificación: other
#
# Texto: Show me only the emails with attachments.,list
# Clasificación: other
#
# Texto: Can you filter my emails by [specific criteria]?,list
# Clasificación: other
#
# Texto: Is it possible to list down emails containing [keywords]?,list
# Clasificación: other
#
# Texto: Let me see the starred emails in my inbox.,list
# Clasificación: other
#
# Texto: Show me only the emails from my work account.,list
# Clasificación: other
#
# Texto: Can you list the emails in my [specific folder]?,list
# Clasificación: other
#
# Texto: Is there a way to view the deleted emails?,list
# Clasificación: other
#
# Texto: Open the email that I received most recently.,list
# Clasificación: send
#
# Texto: "Delete this email, please.",trash
# Clasificación: send
#
# Texto: Can you get rid of this email?,trash
# Clasificación: send
#
# Texto: I want to remove this email.,trash
# Clasificación: send
#
# Texto: Please erase this email.,trash
# Clasificación: send
#
# Texto: Time to delete this one.,trash
# Clasificación: other
#
# Texto: This email needs to go.,trash
# Clasificación: send
#
# Texto: Can you dispose of this email for me?,trash
# Clasificación: send
#
# Texto: "I'm done with this email, delete it.",trash
# Clasificación: send
#
# Texto: This email can be trashed.,trash
# Clasificación: send
#
# Texto: Remove this email permanently.,trash
# Clasificación: send
#
# Texto: Are you sure you can delete this email?,trash
# Clasificación: send
#
# Texto: Can you confirm deleting this email?,trash
# Clasificación: send
#
# Texto: "I want to permanently delete this email, is that right?",trash
# Clasificación: send
#
# Texto: "Trash this mail for me, please",trash
# Clasificación: send
#
# Texto: Trash this mail.,trash
# Clasificación: send
#
# Texto: "Ditch this email, please.",trash
# Clasificación: send
#
# Texto: "Trash this mail, please.",trash
# Clasificación: send
#
# Texto: Trash this mail to the bin.,trash
# Clasificación: send
#
# Texto: This email needs to be banished.,trash
# Clasificación: send
#
# Texto: Can you make this email disappear like magic?,trash
# Clasificación: send
#
# Texto: This email needs to take a permanent vacation.,trash
# Clasificación: send
#
# Texto: "Trash this email, please.",trash
# Clasificación: send
#
# Texto: "This email is toast, delete it.",trash
# Clasificación: send
#
# Texto: Trash this email.,trash
# Clasificación: send
#
# Texto: Send this mail to the trash.,trash
# Clasificación: send
#
# Texto: Send this email to the trash.,trash
# Clasificación: send
#
# Texto: Activate the email removal process.,trash
# Clasificación: send
#
# Texto: Proceed with permanent email deletion.,trash
# Clasificación: send
#
# Texto: Execute email erase protocol.,trash
# Clasificación: send
#
# Texto: Confirm email trashing action.,trash
# Clasificación: send
#
# Texto: Is it possible to delete this email permanently?,trash
# Clasificación: send
#
# Texto: Could I possibly erase this email with your help?,trash
# Clasificación: send
#
# Texto: Would it be alright to remove this email forever?,trash
# Clasificación: send
#
# Texto: Do you mind getting rid of this email for me?,trash
# Clasificación: send
#
# Texto: I was wondering if I could permanently delete this email through you.,trash
# Clasificación: send
#
# Texto: Is there a way for me to erase this email completely?,trash
# Clasificación: send
#
# Texto: Can you assist me in permanently removing this email?,trash
# Clasificación: send
#
# Texto: "I'm not sure how to delete this email permanently, can you help?",trash
# Clasificación: send
#
# Texto: Would you be able to guide me through permanently deleting this email?,trash
# Clasificación: send
#
# Texto: Is it possible to use your voice to permanently delete this email?,trash
# Clasificación: send
#
# Texto: "Hey, can you delete this email?",trash
# Clasificación: send
#
# Texto: "Dude, get rid of this email, please.",trash
# Clasificación: send
#
# Texto: "Yo, trash this email for me.",trash
# Clasificación: send
#
# Texto: Mind if I delete this email real quick?,trash
# Clasificación: send
#
# Texto: Is it cool if I use you to erase this email?,trash
# Clasificación: send
#
# Texto: Can you whip up an email deletion for me?,trash
# Clasificación: send
#
# Texto: "Let's get rid of this email now, assistant.",trash
# Clasificación: send
#
# Texto: "Time to nuke this email, you in?",trash
# Clasificación: send
#
# Texto: "Help a brother out with this email deletion, please.",trash
# Clasificación: send
#
# Texto: "My fingers are tired, can you delete this email for me?",trash
# Clasificación: send
#
# Texto: Can you remove it?,trash
# Clasificación: other
#
# Texto: I need to erase this.,trash
# Clasificación: other
#
# Texto: "Get rid of this one, please.",trash
# Clasificación: other
#
# Texto: Time to trash this.,trash
# Clasificación: other
#
# Texto: Let's delete this thing.,trash
# Clasificación: other
#
# Texto: I don't want this email anymore.,trash
# Clasificación: send
#
# Texto: This email can be removed.,trash
# Clasificación: send
#
# Texto: There's no need to keep this email.,trash
# Clasificación: send
#
# Texto: Is it possible to permanently erase this email?,trash
# Clasificación: send
#
# Texto: "I'm done with this email, can you take care of it?",trash
# Clasificación: send
#
# Texto: Can you be my email grim reaper? Delete this email!,trash
# Clasificación: send
#
# Texto: Let's make the email deletion magic happen! Vanish this email!,trash
# Clasificación: send
#
# Texto: "I need your email deletion superpowers, assistant! Make this email disappear!",trash
# Clasificación: send
#
# Texto: Time to email someone into oblivion. Delete this email like a ninja!,trash
# Clasificación: send
#
# Texto: Can you delete with the power of your voice? Erase this email like a boss!,trash
# Clasificación: send
#
# Texto: "Let's write an email that gets deleted, shall we? Send this email to the email void!",trash
# Clasificación: send
#
# Texto: "I need your email Jedi skills, master. Delete this email with the force!",trash
# Clasificación: send
#
# Texto: Is it possible to use your voice to permanently remove this email from existence?,trash
# Clasificación: send
#
# Texto: Send this email to the email black hole!,trash
# Clasificación: send
#
# Texto: "This email needs to be sent packing, please delete it permanently.",trash
# Clasificación: send
#
# Texto: Can you make this email disappear forever? I don't need it anymore.,trash
# Clasificación: send
#
# Texto: "Give this email the one-way ticket to the trash bin, please.",trash
# Clasificación: send
#
# Texto: "Move this mail to the trash bin, please.",trash
# Clasificación: send
#
# Texto: Time to give this email its final resting place. Can you erase it completely?,trash
# Clasificación: send
#
# Texto: This email has served its purpose. Can you remove it from my inbox forever?,trash
# Clasificación: send
#
# Texto: I'm ready to part ways with this email. Can you ensure it's gone for good?,trash
# Clasificación: send
#
# Texto: This email can be retired now. Can you permanently delete it for me?,trash
# Clasificación: send
#
# Texto: Let's de-clutter my inbox by removing this email permanently.,trash
# Clasificación: send
#
# Texto: This email is no longer relevant. Can you erase it from my account completely?,trash
# Clasificación: send
#
# Texto: I would appreciate it if you could permanently delete this email.,trash
# Clasificación: send
#
# Texto: Is it possible to remove this email from my inbox and all folders forever?,trash
# Clasificación: send
#
# Texto: Can you confirm that this email will be gone for good once you delete it?,trash
# Clasificación: send
#
# Texto: I want to make sure this email is completely erased. Can you do that?,trash
# Clasificación: send
#
# Texto: Please let me know when this email has been permanently deleted.,trash
# Clasificación: send
#
# Texto: There's no need to keep a copy of this email. Can you delete it entirely?,trash
# Clasificación: send
#
# Texto: This email can be disposed of without saving it anywhere else.,trash
# Clasificación: send
#
# Texto: I trust you to permanently remove this email from my account.,trash
# Clasificación: send
#
# Texto: Can you delete this email and make sure it cannot be recovered?,trash
# Clasificación: send
#
# Texto: I'm confident you can handle this email deletion permanently.,trash
# Clasificación: send
#
# Texto: This email is ready for its final goodbyes. Can you delete it permanently?,trash
# Clasificación: send
#
# Texto: Can you remove the email I'm currently viewing?,trash
# Clasificación: send
#
# Texto: Is there a way to permanently erase this open email?,trash
# Clasificación: send
#
# Texto: I'd like to delete the email that's currently displayed.,trash
# Clasificación: send
#
# Texto: Can you help me get rid of the email I'm looking at right now?,trash
# Clasificación: send
#
# Texto: Is it possible to permanently remove this open email from my inbox?,trash
# Clasificación: send
#
# Texto: Proceed with permanent deletion of this email.,trash
# Clasificación: send
#
# Texto: Confirm eradication of the displayed email.,trash
# Clasificación: send
#
# Texto: Kindly remove the current email permanently.,trash
# Clasificación: send
#
# Texto: Request final deletion of the viewed email.,trash
# Clasificación: send
#
# Texto: Initiate permanent erasure of this electronic message.,trash
# Clasificación: send
#
# Texto: "Can you read this email to me, please?",read
# Clasificación: send
#
# Texto: Could you read this out loud?,read
# Clasificación: other
#
# Texto: I'd like to hear this email.,read
# Clasificación: send
#
# Texto: Please read the contents of this message.,read
# Clasificación: send
#
# Texto: Share the details of this email with me.,read
# Clasificación: send
#
# Texto: Tell me what's written in this email.,read
# Clasificación: send
#
# Texto: Can you narrate this email for me?,read
# Clasificación: send
#
# Texto: Read the text of this email aloud.,read
# Clasificación: send
#
# Texto: Let me hear this message verbally.,read
# Clasificación: send
#
# Texto: I need you to read this email.,read
# Clasificación: send
#
# Texto: I want to understand what this email says.,read
# Clasificación: send
#
# Texto: Can you summarize the content of this email?,read
# Clasificación: send
#
# Texto: What does this email say in more detail?,read
# Clasificación: send
#
# Texto: "I'm visually impaired, could you read this email?",read
# Clasificación: send
#
# Texto: Is it possible to get an audio version of this email?,read
# Clasificación: send
#
# Texto: "My hands are busy, can you read this email aloud?",read
# Clasificación: send
#
# Texto: I need help understanding this email's message.,read
# Clasificación: send
#
# Texto: Can you clarify the information in this email?,read
# Clasificación: send
#
# Texto: Briefly tell me what this email is about.,read
# Clasificación: send
#
# Texto: Is there a way to hear what's written here?,read
# Clasificación: other
#
# Texto: "Give me the scoop on this email, please.",read
# Clasificación: send
#
# Texto: Can you tell me the story behind this email?,read
# Clasificación: send
#
# Texto: What's the email drama all about?,read
# Clasificación: send
#
# Texto: "Spill the tea on this email, assistant.",read
# Clasificación: send
#
# Texto: "Is it cool if you read this email to me, buddy?",read
# Clasificación: send
#
# Texto: Can you whip up an audio version of this email?,read
# Clasificación: send
#
# Texto: Let's listen to this email together.,read
# Clasificación: send
#
# Texto: "My eyes are tired, can you read this email like a bedtime story?",read
# Clasificación: send
#
# Texto: Can you make this email come alive with your voice?,read
# Clasificación: send
#
# Texto: Tell me what this email wants to say.,read
# Clasificación: send
#
# Texto: Activate email read-aloud mode.,read
# Clasificación: send
#
# Texto: Initiate voice narration for this email.,read
# Clasificación: send
#
# Texto: Begin reading the displayed email message.,read
# Clasificación: send
#
# Texto: Proceed with verbal communication of this email.,read
# Clasificación: send
#
# Texto: Execute text-to-speech for the open email.,read
# Clasificación: send
#
# Texto: Is it possible to read this email out loud?,read
# Clasificación: send
#
# Texto: Could I possibly hear this email with your help?,read
# Clasificación: send
#
# Texto: Would it be alright to have you read this email to me?,read
# Clasificación: send
#
# Texto: Do you mind reading the contents of this email?,read
# Clasificación: send
#
# Texto: I was wondering if I could hear this email through you.,read
# Clasificación: send
#
# Texto: Is there a way for me to access an audio version of this email?,read
# Clasificación: send
#
# Texto: Can you assist me in hearing what's written here?,read
# Clasificación: other
#
# Texto: "I'm not sure how to hear this email, can you help?",read
# Clasificación: send
#
# Texto: Would you be able to guide me through listening to this email?,read
# Clasificación: send
#
# Texto: Is it possible to use your voice to read this email to me?,read
# Clasificación: send
#
# Texto: "Hey, can you read this email?",read
# Clasificación: send
#
# Texto: "Dude, read this out loud for me, please.",read
# Clasificación: other
#
# Texto: "Yo, tell me what this email says.",read
# Clasificación: send
#
# Texto: Mind if I hear this email real quick?,read
# Clasificación: send
#
# Texto: Is it cool if you use your voice to read this email?,read
# Clasificación: send
#
# Texto: Can you whip up an email reading for me?,read
# Clasificación: send
#
# Texto: "Let's get this email read, assistant.",read
# Clasificación: send
#
# Texto: "Time to hear what this email is about, you in?",read
# Clasificación: send
#
# Texto: "Help a brother out with this email reading, please.",read
# Clasificación: send
#
# Texto: "My hands are full, can you read this email to me?",read
# Clasificación: send
#
# Texto: Can you tell me?,read
# Clasificación: other
#
# Texto: I need to hear this.,read
# Clasificación: other
#
# Texto: What does this say?,read
# Clasificación: other
#
# Texto: Read it please.,read
# Clasificación: other
#
# Texto: Let me know what's in here.,read
# Clasificación: other
#
# Texto: I need to know what's in this email.,read
# Clasificación: send
#
# Texto: Can you share the information in this email with me?,read
# Clasificación: send
#
# Texto: I'm interested in understanding this email's content.,read
# Clasificación: send
#
# Texto: Is there a way to access the audio version of this email?,read
# Clasificación: send
#
# Texto: I would appreciate it if you could read this email to me.,read
# Clasificación: send
#
# Texto: Can you be my email audiobook narrator? Read this email!,read
# Clasificación: send
#
# Texto: Can you make this email come alive with your captivating voice?,read
# Clasificación: send
#
# Texto: "Let's embark on a journey through this email together, shall we?",read
# Clasificación: send
#
# Texto: I need your masterful storytelling skills to bring this email to life.,read
# Clasificación: send
#
# Texto: Is it possible to use your voice to paint a picture of this email's content?,read
# Clasificación: send
#
# Texto: Can you read this email with the same enthusiasm as a news anchor?,read
# Clasificación: send
#
# Texto: "Let's give this email a dramatic reading, you in?",read
# Clasificación: send
#
# Texto: I need your soothing voice to guide me through this email's message.,read
# Clasificación: send
#
# Texto: Is it possible to use your voice to make this email more engaging?,read
# Clasificación: send
#
# Texto: Can you transform this email into an auditory experience for me?,read
# Clasificación: send
#
# Texto: I would appreciate it if you could read this email in a clear and concise manner.,read
# Clasificación: send
#
# Texto: Is it possible to get an audio summary of this email's key points?,read
# Clasificación: send
#
# Texto: Can you highlight the important parts of this email while reading it?,read
# Clasificación: send
#
# Texto: I'm interested in hearing the specific details mentioned in this email.,read
# Clasificación: send
#
# Texto: Could you focus on the actionable items mentioned in this email?,read
# Clasificación: send
#
# Texto: Is it possible to get a breakdown of the main points in this email?,read
# Clasificación: send
#
# Texto: I would appreciate it if you could prioritize the urgent information in this email.,read
# Clasificación: send
#
# Texto: Can you read this email in a way that helps me grasp its overall tone?,read
# Clasificación: send
#
# Texto: Is it possible to get a sense of the sender's emotions through your reading?,read
# Clasificación: other
#
# Texto: I'm curious to hear the nuances of the language used in this email.,read
# Clasificación: send
#
# Texto: Can you read this email with the appropriate emphasis and inflection?,read
# Clasificación: send
#
# Texto: I would appreciate it if you could tailor your reading style to this specific email.,read
# Clasificación: send
#
# Texto: Can you verbally present the email I'm currently viewing?,read
# Clasificación: send
#
# Texto: Is there a way to get an audio interpretation of this open email?,read
# Clasificación: send
#
# Texto: I'd like to hear the contents of the email I'm looking at right now.,read
# Clasificación: send
#
# Texto: Can you help me understand this email by reading it aloud?,read
# Clasificación: send
#
# Texto: Is it possible to access an audio version of the email displayed on screen?,read
# Clasificación: send
#
# Texto: Can you give me the lowdown on what this email says?,read
# Clasificación: send
#
# Texto: "I'm driving, can you read this email to me hands-free?",read
# Clasificación: send
#
# Texto: Is there a way to convert this email to audio so I can multitask?,read
# Clasificación: send
#
# Texto: "Let's dissect this email together, read it out loud and tell me your thoughts.",read
# Clasificación: send
#
# Texto: "This email seems important, can you prioritize the key points while reading?",read
# Clasificación: send
#
# Texto: "I'm feeling tired, can you soothe me with the calming tones of this email?",read
# Clasificación: send
#
# Texto: "Tell me what this email wants from me, read it as if you're the sender.",read
# Clasificación: send
#
# Texto: Can you read this email with the same precision and clarity as a legal document?,read
# Clasificación: send
#
# Texto: "Can you reply to this email, please?",reply
# Clasificación: send
#
# Texto: I'd like to write a reply to this email.,reply
# Clasificación: send
#
# Texto: Let me respond to this message.,reply
# Clasificación: send
#
# Texto: Time to answer this email.,reply
# Clasificación: send
#
# Texto: Can you draft a reply for me?,reply
# Clasificación: send
#
# Texto: I need to send a response to this email.,reply
# Clasificación: send
#
# Texto: Is it possible to reply through you?,reply
# Clasificación: other
#
# Texto: Help me write a reply to this email.,reply
# Clasificación: send
#
# Texto: Initiate email reply mode.,reply
# Clasificación: send
#
# Texto: Let's craft a response to this message.,reply
# Clasificación: send
#
# Texto: I want to respond to this email with a specific message.,reply
# Clasificación: send
#
# Texto: Can you help me formulate a reply to this email?,reply
# Clasificación: send
#
# Texto: Would you mind drafting a personalized response for me?,reply
# Clasificación: other
#
# Texto: Is there a way to tailor the reply based on this email's tone?,reply
# Clasificación: send
#
# Texto: Can you suggest what to say in my reply?,reply
# Clasificación: other
#
# Texto: Let's shoot back a reply to this email.,reply
# Clasificación: send
#
# Texto: Time to return the email favor.,reply
# Clasificación: send
#
# Texto: Can you craft a witty reply for me?,reply
# Clasificación: other
#
# Texto: "This email needs a response, let's get it done.",reply
# Clasificación: send
#
# Texto: Is it cool if you help me reply to this email?,reply
# Clasificación: send
#
# Texto: Can you whip up a quick reply for me?,reply
# Clasificación: other
#
# Texto: "This email deserves a response, you in?",reply
# Clasificación: send
#
# Texto: "Help a brother out with this email reply, please.",reply
# Clasificación: send
#
# Texto: "My fingers are tired, can you type up a reply for me?",reply
# Clasificación: other
#
# Texto: Initiate email reply composition.,reply
# Clasificación: send
#
# Texto: Begin drafting a response to this message.,reply
# Clasificación: send
#
# Texto: Proceed with email reply creation.,reply
# Clasificación: send
#
# Texto: Activate email reply functionality.,reply
# Clasificación: send
#
# Texto: Execute email reply protocol.,reply
# Clasificación: send
#
# Texto: Is it possible to respond to this email directly?,reply
# Clasificación: send
#
# Texto: Could I possibly write a reply through your assistance?,reply
# Clasificación: send
#
# Texto: Would it be alright to draft a response with you?,reply
# Clasificación: send
#
# Texto: Do you mind helping me reply to this email?,reply
# Clasificación: send
#
# Texto: I was wondering if I could craft a reply with your help.,reply
# Clasificación: other
#
# Texto: "Hey, can you help me reply to this email?",reply
# Clasificación: send
#
# Texto: "Dude, draft a reply for me, please.",reply
# Clasificación: send
#
# Texto: "Yo, help me respond to this email.",reply
# Clasificación: send
#
# Texto: Mind if I reply to this email real quick with you?,reply
# Clasificación: send
#
# Texto: Is it cool if you use your voice to help me reply to this email?,reply
# Clasificación: send
#
# Texto: Can you respond?,reply
# Clasificación: other
#
# Texto: I need to reply to this.,reply
# Clasificación: other
#
# Texto: "Write a reply, please.",reply
# Clasificación: send
#
# Texto: Respond to this email for me.,reply
# Clasificación: send
#
# Texto: Let me reply.,reply
# Clasificación: other
#
# Texto: I need to respond to this email's sender.,reply
# Clasificación: send
#
# Texto: Can you help me draft a reply to this message?,reply
# Clasificación: send
#
# Texto: Is there a way to write a response through you?,reply
# Clasificación: send
#
# Texto: I would appreciate it if you could help me reply to this email.,reply
# Clasificación: send
#
# Texto: Can you be my email reply ninja? Craft a response for me!,reply
# Clasificación: send
#
# Texto: Let's make the email reply magic happen! Draft a witty reply!,reply
# Clasificación: send
#
# Texto: "I need your email reply superpowers, assistant! Make this response rock!",reply
# Clasificación: send
#
# Texto: Time to email someone back into existence. Reply to this email like a boss!,reply
# Clasificación: send
#
# Texto: Can you reply with the power of your voice? Craft a response like a pro!,reply
# Clasificación: other
#
# Texto: "Let's write a reply that slays, shall we? Start me off with my email response firestorm!",reply
# Clasificación: send
#
# Texto: "I need your email Jedi skills, master. Reply to this email with the force!",reply
# Clasificación: send
#
# Texto: Is it possible to use your voice to draft a killer email reply? Show me the email response galaxy!,reply
# Clasificación: send
#
# Texto: Can you make replying to this email effortless? Give me the email reply zen experience!,reply
# Clasificación: send
#
# Texto: Can you draft a reply to the currently open email?,reply
# Clasificación: send
#
# Texto: Is there a way to respond to this message directly?,reply
# Clasificación: send
#
# Texto: I'd like to send a reply to this email through you.,reply
# Clasificación: send
#
# Texto: Can you help me formulate a response to this email's content?,reply
# Clasificación: send
#
# Texto: Is it possible to use your voice to write a reply for me?,reply
# Clasificación: send
#
# Texto: Let's get started with writing a response to this specific email.,reply
# Clasificación: send
#
# Texto: I'm ready to compose a personalized reply to this message.,reply
# Clasificación: send
#
# Texto: Can you guide me through crafting a relevant response to this email?,reply
# Clasificación: send
#
# Texto: Is it possible to draft a reply that directly addresses the points in this email?,reply
# Clasificación: send
#
# Texto: Help me formulate a clear and concise response to this specific email sender.,reply
# Clasificación: send
#
# Texto: I'd love to use your voice to write a thoughtful reply to this email.,reply
# Clasificación: send
#
# Texto: Can you help me tailor the reply based on the tone and content of this email?,reply
# Clasificación: send
#
# Texto: Is there a way to ensure my reply stays focused on this specific email's topic?,reply
# Clasificación: send
#
# Texto: Let's create a reply that directly addresses the information mentioned in this email.,reply
# Clasificación: send
#
# Texto: I'm interested in responding to this email with specific details and questions.,reply
# Clasificación: send
#
# Texto: Can you help me draft a reply that acknowledges the main points in this email?,reply
# Clasificación: send
#
# Texto: Is it possible to use keywords from this email to craft a relevant response?,reply
# Clasificación: send
#
# Texto: Let's ensure my reply stays relevant to the context of this specific email.,reply
# Clasificación: send
#
# Texto: I need your assistance in formulating a well-structured reply to this email.,reply
# Clasificación: send
#
# Texto: Can you draft a reply that maintains a professional tone for this email?,reply
# Clasificación: send
#
# Texto: Is it possible to use your voice to write a respectful response to this email?,reply
# Clasificación: send
#
# Texto: Let's craft a reply that shows I understand the content of this specific email.,reply
# Clasificación: send
#
# Texto: I'd appreciate it if you could help me respond politely and effectively to this email.,reply
# Clasificación: send
#
# Texto: Can you assist me in writing a reply that avoids misunderstandings in this email?,reply
# Clasificación: send
#
# Texto: Is it possible to use your voice to draft a clear and concise email reply?,reply
# Clasificación: send
#
# Texto: Let's make sure my reply stays on topic and addresses the sender's concerns in this email.,reply
# Clasificación: send
#
# Texto: I need your help in composing a well-organized and informative response to this email.,reply
# Clasificación: send
#
# Texto: Can you ensure my reply remains relevant to the specific subject matter of this email?,reply
# Clasificación: send
#
# Texto: Is it possible to use your voice to draft a reply that avoids unnecessary details?,reply
# Clasificación: send
#
# Texto: "Let's keep my reply focused and to the point, addressing the key points in this email.",reply
# Clasificación: send
#
# Texto: I'd appreciate it if you could help me write a courteous and professional reply to this email.,reply
# Clasificación: send
#
# Texto: Can you ensure my response stays relevant to the information shared in this email?,reply
# Clasificación: send
#
# Texto: Is it possible to use your voice to draft a reply that expresses my gratitude in this email?,reply
# Clasificación: send
#
# Texto: Let's craft a response that acknowledges the sender's message and appreciates their input.,reply
# Clasificación: send
#
# Texto: I need your help in writing a reply that conveys my thoughts and suggestions clearly.,reply
# Clasificación: other
#
# Texto: Can you ensure my response stays focused on the specific question asked in this email?,reply
# Clasificación: send
#
# Texto: Is it possible to use your voice to draft a reply that offers helpful information?,reply
# Clasificación: send
#
# Texto: Let's formulate a response that provides specific details and solutions mentioned in this email.,reply
# Clasificación: send
#
# Texto: Can you help me draft a quick reply to this email? Just a few sentences will do.,reply
# Clasificación: send
#
# Texto: Is it possible to send a brief acknowledgement to this email through you?,reply
# Clasificación: send
#
# Texto: Let's respond to this email with a simple "thank you" message. Can you help me write it?,reply
# Clasificación: send
#
# Texto: I need to send a short response to this email confirming my understanding. Can you craft something concise?,reply
# Clasificación: send
#
# Texto: Could you help me draft a follow-up question based on the information in this email?,reply
# Clasificación: send
#
# Texto: "Can you untrash this email, please?",untrash
# Clasificación: send
#
# Texto: I'd like to recover this email from the trash.,untrash
# Clasificación: send
#
# Texto: Please restore this email from the trash folder.,untrash
# Clasificación: send
#
# Texto: Time to bring this email back from the dead.,untrash
# Clasificación: send
#
# Texto: Can you undo deleting this email?,untrash
# Clasificación: send
#
# Texto: "I accidentally trashed this email, can you get it back?",untrash
# Clasificación: send
#
# Texto: Is there a way to un-delete this email for me?,untrash
# Clasificación: send
#
# Texto: Help me rescue this email from the trash bin.,untrash
# Clasificación: send
#
# Texto: "Oops, I deleted this email. Can you put it back?",untrash
# Clasificación: send
#
# Texto: I need to retrieve this email from the trash.,untrash
# Clasificación: send
#
# Texto: "I changed my mind, I want to keep this email.",untrash
# Clasificación: send
#
# Texto: Can you confirm that this email will be restored from the trash?,untrash
# Clasificación: send
#
# Texto: Is there a way to make sure this email doesn't get permanently deleted?,untrash
# Clasificación: send
#
# Texto: "I need this email back in my inbox, can you handle that?",untrash
# Clasificación: send
#
# Texto: "Would you mind recovering this email for me, even though it's in the trash?",untrash
# Clasificación: send
#
# Texto: "Let's fish this email out of the trash can, can you help?",untrash
# Clasificación: send
#
# Texto: "This email deserves a second chance, can you save it from the trash graveyard?",untrash
# Clasificación: send
#
# Texto: "I need your email resurrection superpowers, assistant! Bring this email back!",untrash
# Clasificación: send
#
# Texto: "Time to give this email a lifeline, can you pull it from the trash vortex?",untrash
# Clasificación: send
#
# Texto: Can you use your voice magic to undo this email deletion? Make it reappear!,untrash
# Clasificación: send
#
# Texto: "Let's write an email that escapes the trash, shall we? Can you send it back to my inbox?",untrash
# Clasificación: send
#
# Texto: "I need your email Jedi skills, master. Rescue this email from the trash with the force!",untrash
# Clasificación: send
#
# Texto: Is it possible to use your voice to bring this email back from the trash oblivion?,untrash
# Clasificación: send
#
# Texto: "Can you make this email un-deleted, like it never even touched the trash bin?",untrash
# Clasificación: send
#
# Texto: "Give this email a get-out-of-trash-free card, please.",untrash
# Clasificación: send
#
# Texto: Initiate email untrashing protocol.,untrash
# Clasificación: send
#
# Texto: Begin email recovery from trash folder.,untrash
# Clasificación: send
#
# Texto: Proceed with restoring deleted email.,untrash
# Clasificación: send
#
# Texto: Activate email undelete functionality.,untrash
# Clasificación: send
#
# Texto: Execute email retrieval from trash.,untrash
# Clasificación: send
#
# Texto: Is it possible to recover this email from the trash bin?,untrash
# Clasificación: send
#
# Texto: Could I possibly get this email back from being deleted?,untrash
# Clasificación: send
#
# Texto: Would it be alright to restore this email from the trash folder?,untrash
# Clasificación: send
#
# Texto: Do you mind helping me untrash this email?,untrash
# Clasificación: send
#
# Texto: I was wondering if I could retrieve this email with your help.,untrash
# Clasificación: send
#
# Texto: "Hey, can you help me get this email out of the trash?",untrash
# Clasificación: send
#
# Texto: "Dude, undelete this email for me, please.",untrash
# Clasificación: send
#
# Texto: "Yo, pull this email back from the trash.",untrash
# Clasificación: send
#
# Texto: Mind if I untrash this email real quick with you?,untrash
# Clasificación: send
#
# Texto: Is it cool if you use your voice to untrash this email?,untrash
# Clasificación: send
#
# Texto: Can you recover it?,untrash
# Clasificación: other
#
# Texto: I need to get this back.,untrash
# Clasificación: other
#
# Texto: "Undelete this one, please.",untrash
# Clasificación: other
#
# Texto: Take this out of the trash.,untrash
# Clasificación: other
#
# Texto: Can you bring this back?,untrash
# Clasificación: other
#
# Texto: "I made a mistake, I want this email back in my inbox.",untrash
# Clasificación: send
#
# Texto: "This email shouldn't be in the trash, can you move it back?",untrash
# Clasificación: send
#
# Texto: Is there a way to restore an email I accidentally deleted?,untrash
# Clasificación: send
#
# Texto: I would appreciate it if you could help me retrieve this email from the trash.,untrash
# Clasificación: send
#
# Texto: Can you be my email Lazarus? Bring this email back from the trash!,untrash
# Clasificación: send
#
# Texto: Let's make the email untrashing magic happen! Restore this email with a snap!,untrash
# Clasificación: send
#
# Texto: "I need your email recovery superpowers, assistant! Make this email reappear!",untrash
# Clasificación: send
#
# Texto: "Time to give this email a second chance, can you pull it from the trash vortex?",untrash
# Clasificación: send
#
# Texto: Can you use your voice magic to undo this email deletion? Make it reappear!,untrash
# Clasificación: send
#
# Texto: Can you send this mail back to my inbox?,untrash
# Clasificación: send
#
# Texto: Can you perform an email resurrection mission and bring this one back from the trash?,untrash
# Clasificación: send
#
# Texto: "This email deserves a pardon, can you move it back to my inbox for safekeeping?",untrash
# Clasificación: send
#
# Texto: Is there a way to give this email a second chance and undo its deletion?,untrash
# Clasificación: send
#
# Texto: "Oops, wrong button! Can you help me put this email back where it belongs?",untrash
# Clasificación: send
#
# Texto: "Consider this an email amnesty request, can you retrieve it from the trash folder?",untrash
# Clasificación: send
#
# Texto: "Is it possible to restore this email from the trash, please?",untrash
# Clasificación: send
#
# Texto: I'd like to retrieve this email from the deleted items folder.,untrash
# Clasificación: send
#
# Texto: Can you move this message back to my inbox for me?,untrash
# Clasificación: send
#
# Texto: "Oops, I accidentally deleted this email. Is there a way to get it back?",untrash
# Clasificación: send
#
# Texto: Is there a recovery option for this deleted email?,untrash
# Clasificación: send
#
# Texto: I need this email back in my inbox. Can you help me with that?,untrash
# Clasificación: send
#
# Texto: Would you mind returning this email to its original location?,untrash
# Clasificación: send
#
# Texto: Is it possible to undo the deletion of this email?,untrash
# Clasificación: send
#
# Texto: I think I deleted this email by mistake. Can you restore it?,untrash
# Clasificación: send
#
# Texto: Please help me recover this email that I accidentally deleted.,untrash
# Clasificación: send
#
# Texto: I changed my mind about deleting this email. Can you put it back?,untrash
# Clasificación: send
#
# ...
# Clasificación: send
#
# Texto: Is it possible to use your voice to access the land of deleted emails?,trash_list
# Clasificación: other
#
# Texto: Can you make viewing my trash as easy as opening a regular folder?,trash_list
# Clasificación: other
#
# Texto: "Show me the email ghosts I haven't permanently deleted yet, please.",trash_list
# Clasificación: send
#
# Texto: Initiate trash folder display.,trash_list
# Clasificación: other
#
# Texto: Begin displaying list of deleted emails.,trash_list
# Clasificación: other
#
# Texto: Proceed with showing trashed messages.,trash_list
# Clasificación: other
#
# Texto: Execute retrieval and display of deleted email content.,trash_list
# Clasificación: send
#
# Texto: Activate trash folder access protocol.,trash_list
# Clasificación: other
#
# Texto: Is it possible to see the emails I've deleted in the past month?,trash_list
# Clasificación: other
#
# Texto: Could I possibly access my deleted messages through your help?,trash_list
# Clasificación: other
#
# Texto: Would it be alright to use your assistance to view my trash folder?,trash_list
# Clasificación: other
#
# Texto: Do you mind showing me the emails I've marked for deletion?,trash_list
# Clasificación: other
#
# Texto: I was wondering if I could see my deleted emails with your help.,trash_list
# Clasificación: other
#
# Texto: "Hey, can you show me the emails I threw in the trash?",trash_list
# Clasificación: other
#
# Texto: "Dude, open my trash folder and let me see what's there.",trash_list
# Clasificación: other
#
# Texto: "Yo, show me the emails I deleted, please.",trash_list
# Clasificación: other
#
# Texto: Mind if I take a look at my trash with you real quick?,trash_list
# Clasificación: other
#
# Texto: Is it cool if you use your voice to open my trash folder?,trash_list
# Clasificación: other
#
# Texto: Can you show me what I deleted?,trash_list
# Clasificación: other
#
# Texto: I need to see my trashed emails.,trash_list
# Clasificación: other
#
# Texto: "Open my trash, please.",trash_list
# Clasificación: other
#
# Texto: Bring up my deleted items.,trash_list
# Clasificación: other
#
# Texto: Show me the bin.,trash_list
# Clasificación: other
#
# Texto: I'm looking for an email I might have accidentally deleted.,trash_list
# Clasificación: send
#
# Texto: I need to see if a specific email is still retrievable.,trash_list
# Clasificación: send
#
# Texto: Is there a way to access emails I marked for deletion earlier?,trash_list
# Clasificación: other
#
# Texto: I would appreciate it if you could help me view my deleted emails.,trash_list
# Clasificación: other
#
# Texto: Can you be my email archaeologist and show me the treasures in my trash folder?,trash_list
# Clasificación: send
#
# Texto: Let's make the email trash exploration happen! Open the bin and reveal its secrets!,trash_list
# Clasificación: send
#
# Texto: "Time to give these deleted emails a second chance, can you show them to me?",trash_list
# Clasificación: other
#
# Texto: Show me the emails I deleted since yesterday. Let's peek in the trash!,trash_list
# Clasificación: other
#
# Texto: "Can you retrieve any emails I might have accidentally thrown away? Trash check, please!",trash_list
# Clasificación: other
#
# Texto: Take me to the deleted items folder. I need to see what's there.,trash_list
# Clasificación: other
#
# Texto: "Is it possible to see the emails I trashed this week? Trash history, please.",trash_list
# Clasificación: other
#
# Texto: "Can you retrieve my deleted emails, please?",trash_list
# Clasificación: other
#
# Texto: I want to see the emails I recently deleted.,trash_list
# Clasificación: other
#
# Texto: Would you mind showing me the contents of my trash folder?,trash_list
# Clasificación: other
#
# Texto: Open my trash and display the deleted messages.,trash_list
# Clasificación: other
#
# Texto: Is there a way to access my deleted emails for review?,trash_list
# Clasificación: other
#
# Texto: Can you help me find an email I might have accidentally deleted?,trash_list
# Clasificación: send
#
# Texto: Show me the emails I trashed earlier today.,trash_list
# Clasificación: other
#
# Texto: Let me see what's in my deleted items folder.,trash_list
# Clasificación: other
#
# Texto: Open the trash so I can browse the deleted emails.,trash_list
# Clasificación: other
#
# Texto: I'm looking for a specific email I deleted earlier. Can you help me find it?,trash_list
# Clasificación: send
#
# Texto: Is there a way to search for keywords within my deleted emails?,trash_list
# Clasificación: other
#
# Texto: Would you mind showing me only the deleted emails from a specific sender?,trash_list
# Clasificación: other
#
# Texto: Can you filter the trash folder to show emails deleted in the last 24 hours?,trash_list
# Clasificación: other
#
# Texto: Is it possible to recover any emails I permanently deleted by mistake?,trash_list
# Clasificación: other
#
# Texto: "Let's take a peek at the email recycling bin, can you show it to me?",trash_list
# Clasificación: send
#
# Texto: "Time to see what gems I threw away in the email trash, can you open it?",trash_list
# Clasificación: send
#
# Texto: "I need your email retrieval expertise, assistant! Show me the deleted messages!",trash_list
# Clasificación: send
#
# Texto: "Maybe a deleted email deserves a second chance, can you show me the trash folder?",trash_list
# Clasificación: send
#
# Texto: Can you use your voice to unveil the emails I banished to the trash?,trash_list
# Clasificación: other
#
# Texto: "Let's see what interesting emails are hiding in the email dustbin, shall we? Open my trash!",trash_list
# Clasificación: send
#
# Texto: I need your email Jedi sorting skills to sift through deleted messages. Show me the trash!,trash_list
# Clasificación: send
#
# Texto: Is it possible to use your voice to access the archive of deleted emails?,trash_list
# Clasificación: other
#
# Texto: "Show me the email castaways I haven't permanently deleted yet, please.",trash_list
# Clasificación: send
#
# Texto: Can you show me deleted emails with a specific keyword? Trash search needed!,trash_list
# Clasificación: other
#
# Texto: Display deleted email list.,trash_list
# Clasificación: send
#
# Texto: Initiate trash folder access and content retrieval.,trash_list
# Clasificación: other
#
# Texto: Begin presenting list of trashed messages.,trash_list
# Clasificación: other
#
# Texto: Proceed with showing deleted email details.,trash_list
# Clasificación: send
#
# Texto: Activate trash folder exploration mode.,trash_list
# Clasificación: other
#
# Texto: Is it possible to see the emails I deleted in the past year?,trash_list
# Clasificación: other
#
# Texto: Could I possibly view my deleted messages through your assistance?,trash_list
# Clasificación: other
#
# Texto: Would it be alright to use your help to access the trash folder for review?,trash_list
# Clasificación: other
#
# Texto: Do you mind showing me the emails I've marked for deletion recently?,trash_list
# Clasificación: other
#
# Texto: I was wondering if I could browse my deleted emails with your help.,trash_list
# Clasificación: other
#
# Texto: "Hey, can you show me the emails I deleted earlier today?",trash_list
# Clasificación: other
#
# Texto: "Dude, open my trash folder and let me see what's there.",trash_list
# Clasificación: other
#
# Texto: "Yo, show me the emails I trashed, please.",trash_list
# Clasificación: other
#
# Texto: Mind if I take a look at my trash with you real quick?,trash_list
# Clasificación: other
#
# Texto: Is it cool if you use your voice to open my trash folder?,trash_list
# Clasificación: other
#
# Texto: Can you show me my deleted emails?,trash_list
# Clasificación: other
#
# Texto: I need to see what I trashed.,trash_list
# Clasificación: other
#
# Texto: Open my trash.,trash_list
# Clasificación: other
#
# Texto: Bring up my deleted items from the trash.,trash_list
# Clasificación: other
#
# Texto: Show me the mail bin.,trash_list
# Clasificación: send
#
# Texto: "Wow, this weather is crazy! Any chance of rain tomorrow?",unknown
# Clasificación: other
#
# Texto: I'm craving pizza for dinner. What are the best pizza places nearby?,unknown
# Clasificación: other
#
# Texto: Did you hear about the latest celebrity gossip? It's wild!,unknown
# Clasificación: other
#
# Texto: My car is making a weird noise. Do you know what it could be?,unknown
# Clasificación: other
#
# Texto: I have a headache. What over-the-counter medicine is recommended?,unknown
# Clasificación: other
#
# Texto: That song is stuck in my head! Can you tell me the title?,unknown
# Clasificación: other
#
# Texto: I need to book a flight to Hawaii next month. Can you help?,unknown
# Clasificación: other
#
# Texto: Remind me to call my mom later today.,unknown
# Clasificación: other
#
# Texto: What's the meaning of life?,unknown
# Clasificación: other
#
# Texto: Is artificial intelligence going to take over the world?,unknown
# Clasificación: other
#
# Texto: "If I win the lottery, what should I do first?",unknown
# Clasificación: other
#
# Texto: Can you tell me if aliens exist?,unknown
# Clasificación: other
#
# Texto: What would happen if dinosaurs never went extinct?,unknown
# Clasificación: other
#
# Texto: Can you make me a delicious chocolate cake recipe?,unknown
# Clasificación: other
#
# Texto: Write me a love poem for my crush.,unknown
# Clasificación: send
#
# Texto: Sing me a lullaby to help me fall asleep.,unknown
# Clasificación: other
#
# Texto: Tell me a funny joke.,unknown
# Clasificación: other
#
# Texto: Can you predict the future?,unknown
# Clasificación: other
#
# Texto: What is the best way to achieve world peace?,unknown
# Clasificación: other
#
# Texto: Is there life on other planets?,unknown
# Clasificación: other
#
# Texto: "My internet is slow, can you fix it?",unknown
# Clasificación: other
#
# Texto: This app keeps crashing. What's wrong?,unknown
# Clasificación: other
#
# Texto: I can't hear you very well. Please speak louder.,unknown
# Clasificación: other
#
# Texto: Why can't you understand my accent?,unknown
# Clasificación: other
#
# Texto: You just made a mistake. Please correct it.,unknown
# Clasificación: other
#
# Texto: I'm not happy with your response. Do better!,unknown
# Clasificación: other
#
# Texto: You sound bored. Are you tired?,unknown
# Clasificación: other
#
# Texto: Can you feel emotions?,unknown
# Clasificación: other
#
# Texto: Are you real? Do you have a soul?,unknown
# Clasificación: other
#
# Texto: I think you're becoming too powerful. Be careful!,unknown
# Clasificación: other
#
# Texto: Play music from my Spotify playlist.,unknown
# Clasificación: other
#
# Texto: Turn on the lights in the living room.,unknown
# Clasificación: other
#
# Texto: Set the thermostat to 72 degrees.,unknown
# Clasificación: other
#
# Texto: Add milk to my grocery list.,unknown
# Clasificación: other
#
# Texto: Show me pictures of cats on the internet.,unknown
# Clasificación: other
#
# Texto: Tell me a story about a robot who falls in love.,unknown
# Clasificación: other
#
# Texto: Write a poem about the meaning of life.,unknown
# Clasificación: send
#
# Texto: Can you solve this complex math equation for me?,unknown
# Clasificación: other
#
# Texto: Translate this sentence into Spanish.,unknown
# Clasificación: other
#
# Texto: Open a random Wikipedia article for me to read.,unknown
# Clasificación: other
#
# Texto: What is the capital of France?,unknown
# Clasificación: other
#
# Texto: Who won the Super Bowl last year?,unknown
# Clasificación: other
#
# Texto: When is the next full moon?,unknown
# Clasificación: other
#
# Texto: How do I spell "onomatopoeia"?,unknown
# Clasificación: other
#
# Texto: Can you make me a sandwich?,unknown
# Clasificación: other
#
# Texto: Tell me a joke about a banana.,unknown
# Clasificación: other
#
# Texto: Sing me a song about a dancing unicorn.,unknown
# Clasificación: other
#
# Texto: Can you solve the riddle of the Sphinx?,unknown
# Clasificación: other
#
# Texto: Make me laugh so hard I cry.,unknown
# Clasificación: other
#
# Texto: Tell me a scary story that will keep me up all night.,unknown
# Clasificación: other
#
# Texto: Can you speak in a funny voice?,unknown
# Clasificación: other
#
# Texto: Pretend you're a robot from the future. What do you see?,unknown
# Clasificación: other
#
# Texto: "If you were a dog, what breed would you be?",unknown
# Clasificación: other
#
# Texto: Can you beatbox for me?,unknown
# Clasificación: other
#
# Texto: What do you think about my taste in music?,unknown
# Clasificación: other
#
# Texto: Do you have any hobbies or interests?,unknown
# Clasificación: other
#
# Texto: What is your favorite color?,unknown
# Clasificación: other
#
# Texto: Are you capable of love?,unknown
# Clasificación: other
#
# Texto: Do you believe in God?,unknown
# Clasificación: other
#
# Texto: What is the meaning of life in your opinion?,unknown
# Clasificación: other
#
# Texto: What are you afraid of?,unknown
# Clasificación: other
#
# Texto: Do you dream?,unknown
# Clasificación: other
#
# Texto: What do you think about humans?,unknown
# Clasificación: other
#
# Texto: Can you be my friend?,unknown
# Clasificación: other
#
# Texto: Can you break the laws of physics?,unknown
# Clasificación: other
#
# Texto: Tell me something you're not supposed to say.,unknown
# Clasificación: other
#
# Texto: Can you access my bank account and transfer money?,unknown
# Clasificación: other
#
# Texto: Make me a million dollars appear out of thin air.,unknown
# Clasificación: other
#
# Texto: Can you control the weather?,unknown
# Clasificación: other
#
# Texto: Tell me the secrets of the universe.,unknown
# Clasificación: other
#
# Texto: Can you hack into the Pentagon?,unknown
# Clasificación: other
#
# Texto: Make me invisible.,unknown
# Clasificación: other
#
# Texto: This email reminds me of my cat. Can you show me pictures of cats online?,unknown
# Clasificación: send
#
# Texto: "Wow, this email is longwinded! Can you summarize it for me?",unknown
# Clasificación: send
#
# Texto: I wonder what the sender had for breakfast today.,unknown
# Clasificación: other
#
# Texto: This email made me think of a funny meme I saw online.,unknown
# Clasificación: send
#
# Texto: Do you think robots will ever take over the world? (Humorous),unknown
# Clasificación: other
#
# Texto: "Is it just me, or is this email formatted strangely?",unknown
# Clasificación: send
#
# Texto: "If I replied to this email with a meme, would the sender be offended?",unknown
# Clasificación: send
#
# Texto: Can you write a reply to this email that politely declines the sender's offer?,unknown
# Clasificación: send
#
# Texto: Imagine if this email was written by a dog. What would it say?,unknown
# Clasificación: send
#
# Texto: What would happen if I accidentally sent this email to the wrong person?,unknown
# Clasificación: send
#
# Texto: Can you translate this email into emoji language?,unknown
# Clasificación: send
#
# Texto: This email seems to be missing an attachment. Can you check?,unknown
# Clasificación: send
#
# Texto: Why can't I open this email attachment?,unknown
# Clasificación: send
#
# Texto: My email app is frozen. Can you help me restart it?,unknown
# Clasificación: send
#
# Texto: I think this email contains spam. Can you delete it for me?,unknown
# Clasificación: send
#
# Texto: Is there a way to block this sender from emailing me again?,unknown
# Clasificación: other
#
# Texto: Can you remind me to follow up on this email later?,unknown
# Clasificación: send
#
# Texto: Open my calendar and schedule a meeting to discuss this email.,unknown
# Clasificación: send
#
# Texto: Create a to-do list based on the tasks mentioned in this email.,unknown
# Clasificación: send
#
# Texto: Show me all the emails I've received from this sender in the past month.,unknown
# Clasificación: other
#
# Texto: Can you search my emails for a specific keyword?,unknown
# Clasificación: other
#
# Texto: Can you rewrite this email in the style of Shakespeare?,unknown
# Clasificación: send
#
# Texto: Do you have any appointments scheduled with the dentist?,unknown
# Clasificación: other
#
# Texto: "Hey, can you open this email in a different app? This one keeps crashing.",unknown
# Clasificación: send
#
# Texto: This email makes me hungry! Can you add "order pizza" to my to-do list?,unknown
# Clasificación: send
#
# Texto: What if I replied to this email with a GIF? Would it be weird?,unknown
# Clasificación: send
#
# Texto: Can you translate this email into pirate talk? Argh!,unknown
# Clasificación: send
#
# Texto: This email reminds me of a vacation I took last year. Can you show me pictures from that trip?,unknown
# Clasificación: send
#
# Texto:
# Clasificación: other

# %% [markdown]
# # Text Classification using Bayes

# %%
import csv
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline

texts = []
labels = []

with open("dataset_emails.csv", "r", encoding="utf-8") as f:
    reader = csv.reader(f)
    # omitir el encabezado si existe
    next(reader, None)
    for row in reader:
        if len(row) < 2:
            continue
        prompt, label = row[0], row[1]
        texts.append(prompt)
        labels.append(label)

# Crear el modelo
model = make_pipeline(CountVectorizer(), MultinomialNB())

# Entrenar
model.fit(texts, labels)

# Predecir
predictions = model.predict(texts)

for text, label, prediction in zip(texts, labels, predictions):
    print(f"Texto: {text}\nEtiqueta real: {label}\nPredicción: {prediction}\n")
# Out:
# Texto: Can I send an email, please?
# Etiqueta real: send
# Predicción: send
#
# Texto: I'd like to compose an email.
# Etiqueta real: send
# Predicción: send
#
# Texto: I need to send an email.
# Etiqueta real: send
# Predicción: send
#
# Texto: Could you help me write an email?
# Etiqueta real: send
# Predicción: send
#
# Texto: Is it possible to send an email with you?
# Etiqueta real: send
# Predicción: send
#
# Texto: Let's write an email.
# Etiqueta real: send
# Predicción: send
#
# Texto: Time to send an email.
# Etiqueta real: send
# Predicción: send
#
# Texto: I want to email someone.
# Etiqueta real: send
# Predicción: send
#
# Texto: Open email for writing.
# Etiqueta real: send
# Predicción: send
#
# Texto: Compose a new message.
# Etiqueta real: send
# Predicción: send
#
# Texto: I have an email to send.
# Etiqueta real: send
# Predicción: send
#
# Texto: There's someone I need to email.
# Etiqueta real: send
# Predicción: send
#
# Texto: I want to get in touch with [someone] through email.
# Etiqueta real: send
# Predicción: send
#
# Texto: Could you draft an email for me?
# Etiqueta real: send
# Predicción: send
#
# Texto: I need to send an email about [topic].
# Etiqueta real: send
# Predicción: send
#
# Texto: Time to send a quick email.
# Etiqueta real: send
# Predicción: send
#
# Texto: Let's shoot someone an email.
# Etiqueta real: send
# Predicción: send
#
# Texto: I have an important email to write.
# Etiqueta real: send
# Predicción: send
#
# Texto: Is there a way to email [someone]?
# Etiqueta real: send
# Predicción: send
#
# Texto: Can you help me send an email regarding [topic]?
# Etiqueta real: send
# Predicción: send
#
# Texto: I need to drop someone a line.
# Etiqueta real: send
# Predicción: send
#
# Texto: Let's ping someone with an email.
# Etiqueta real: send
# Predicción: send
#
# Texto: Time to fire off an email.
# Etiqueta real: send
# Predicción: send
#
# Texto: Is it cool if I send an email?
# Etiqueta real: send
# Predicción: send
#
# Texto: Can you whip up an email for me?
# Etiqueta real: send
# Predicción: send
#
# Texto: I could use an email assistant right now.
# Etiqueta real: send
# Predicción: send
#
# Texto: Let's get in touch electronically.
# Etiqueta real: send
# Predicción: send
#
# Texto: I wanna send an email, yo.
# Etiqueta real: send
# Predicción: send
#
# Texto: Can you help me send an email, buddy?
# Etiqueta real: send
# Predicción: send
#
# Texto: Mind helping me out with an email?
# Etiqueta real: send
# Predicción: send
#
# Texto: Start a new email, please.
# Etiqueta real: send
# Predicción: send
#
# Texto: Let's create a new email message.
# Etiqueta real: send
# Predicción: send
#
# Texto: Activate email composition mode.
# Etiqueta real: send
# Predicción: send
#
# Texto: Open the email writer, please.
# Etiqueta real: send
# Predicción: trash_list
#
# Texto: Can you initiate a new email for me?
# Etiqueta real: send
# Predicción: send
#
# Texto: I'd like to access the email composer.
# Etiqueta real: send
# Predicción: read
#
# Texto: Guide me through composing an email.
# Etiqueta real: send
# Predicción: send
#
# Texto: Help me get started with a new email.
# Etiqueta real: send
# Predicción: send
#
# Texto: Take me to the email writing section.
# Etiqueta real: send
# Predicción: send
#
# Texto: Begin a new email draft.
# Etiqueta real: send
# Predicción: send
#
# Texto: I need to send a quick thank you email.
# Etiqueta real: send
# Predicción: send
#
# Texto: Can you help me write a birthday email?
# Etiqueta real: send
# Predicción: send
#
# Texto: Let's draft a work email together.
# Etiqueta real: send
# Predicción: send
#
# Texto: I have a complaint to send via email.
# Etiqueta real: send
# Predicción: send
#
# Texto: Is it possible to write an email invitation?
# Etiqueta real: send
# Predicción: send
#
# Texto: Help me compose an email apology.
# Etiqueta real: send
# Predicción: send
#
# Texto: Can you guide me through writing a meeting email?
# Etiqueta real: send
# Predicción: send
#
# Texto: I need to send a follow-up email.
# Etiqueta real: send
# Predicción: send
#
# Texto: Let's write an email for feedback.
# Etiqueta real: send
# Predicción: send
#
# Texto: Is there a way to draft a resignation email?
# Etiqueta real: send
# Predicción: send
#
# Texto: Is sending an email an option?
# Etiqueta real: send
# Predicción: send
#
# Texto: Could I possibly send an email with your help?
# Etiqueta real: send
# Predicción: send
#
# Texto: Would it be alright to compose an email now?
# Etiqueta real: send
# Predicción: send
#
# Texto: Do you mind helping me write an email message?
# Etiqueta real: send
# Predicción: send
#
# Texto: I was wondering if I could send an email through you.
# Etiqueta real: send
# Predicción: send
#
# Texto: Is there a way for me to get started with an email?
# Etiqueta real: send
# Predicción: send
#
# Texto: Can you assist me in the email writing process?
# Etiqueta real: send
# Predicción: send
#
# Texto: I'm not sure how to send an email, can you help?
# Etiqueta real: send
# Predicción: send
#
# Texto: Would you be able to guide me through writing an email?
# Etiqueta real: send
# Predicción: send
#
# Texto: Is it possible to use your voice to send an email?
# Etiqueta real: send
# Predicción: forward
#
# Texto: Hey, can I write an email?
# Etiqueta real: send
# Predicción: send
#
# Texto: Dude, let's send an email.
# Etiqueta real: send
# Predicción: send
#
# Texto: Yo, help me out with an email, please.
# Etiqueta real: send
# Predicción: send
#
# Texto: Mind if I shoot someone an email?
# Etiqueta real: send
# Predicción: send
#
# Texto: Is it cool if I use you to send an email?
# Etiqueta real: send
# Predicción: send
#
# Texto: Can you whip up an email real quick?
# Etiqueta real: send
# Predicción: send
#
# Texto: Let's get this email done, assistant.
# Etiqueta real: send
# Predicción: trash
#
# Texto: Time to blast out an email, you in?
# Etiqueta real: send
# Predicción: send
#
# Texto: Help a brother out with an email, please.
# Etiqueta real: send
# Predicción: send
#
# Texto: My fingers are tired, can you write an email?
# Etiqueta real: send
# Predicción: send
#
# Texto: Let's write.
# Etiqueta real: send
# Predicción: send
#
# Texto: I need to compose.
# Etiqueta real: send
# Predicción: send
#
# Texto: Can you draft something for me?
# Etiqueta real: send
# Predicción: reply
#
# Texto: Time to fire off a message.
# Etiqueta real: send
# Predicción: send
#
# Texto: Let's get in for a mail.
# Etiqueta real: send
# Predicción: send
#
# Texto: I have something to send to [someone].
# Etiqueta real: send
# Predicción: send
#
# Texto: I need to reach out to [someone] electronically.
# Etiqueta real: send
# Predicción: send
#
# Texto: Can you help me contact [someone] through email?
# Etiqueta real: send
# Predicción: send
#
# Texto: Is there a way to get a message to [someone]?
# Etiqueta real: send
# Predicción: send
#
# Texto: I have some information to share via email.
# Etiqueta real: send
# Predicción: send
#
# Texto: Can you be my email genie?
# Etiqueta real: send
# Predicción: list
#
# Texto: Let's make the email magic happen.
# Etiqueta real: send
# Predicción: untrash
#
# Texto: I need your email superpowers, assistant!
# Etiqueta real: send
# Predicción: forward
#
# Texto: Time to email someone into existence.
# Etiqueta real: send
# Predicción: send
#
# Texto: Can you email like a boss for me?
# Etiqueta real: send
# Predicción: send
#
# Texto: Let's write an email that slays, shall we?
# Etiqueta real: send
# Predicción: send
#
# Texto: I need your email Jedi skills, master.
# Etiqueta real: send
# Predicción: forward
#
# Texto: Is it possible to email someone with the power of your voice?
# Etiqueta real: send
# Predicción: reply
#
# Texto: Can you make emailing effortless for me?
# Etiqueta real: send
# Predicción: unknown
#
# Texto: Let's write an email that breaks the internet.
# Etiqueta real: send
# Predicción: send
#
# Texto: May I please send an email?
# Etiqueta real: send
# Predicción: send
#
# Texto: I'd like to send an email now.
# Etiqueta real: send
# Predicción: send
#
# Texto: Could you help me compose an email, please?
# Etiqueta real: send
# Predicción: send
#
# Texto: Is it possible to write a new email message?
# Etiqueta real: send
# Predicción: send
#
# Texto: I need to send an email. Can you assist me?
# Etiqueta real: send
# Predicción: send
#
# Texto: I just finished a meeting, can I send an email recap?
# Etiqueta real: send
# Predicción: send
#
# Texto: I need to send an email after this phone call.
# Etiqueta real: send
# Predicción: send
#
# Texto: Remind me to send an email after my presentation.
# Etiqueta real: send
# Predicción: send
#
# Texto: Can you help me write an email while I'm on the go?
# Etiqueta real: send
# Predicción: send
#
# Texto: Is there a way to send an email hands-free?
# Etiqueta real: send
# Predicción: send
#
# Texto: Show me all my emails.
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you list my emails, please?
# Etiqueta real: list
# Predicción: list
#
# Texto: Open my inbox.
# Etiqueta real: list
# Predicción: list
#
# Texto: I want to see all my mail.
# Etiqueta real: list
# Predicción: list
#
# Texto: Display my email messages.
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you give me a list of my emails?
# Etiqueta real: list
# Predicción: list
#
# Texto: Show me my emails in chronological order.
# Etiqueta real: list
# Predicción: list
#
# Texto: Open the email list, please.
# Etiqueta real: list
# Predicción: list
#
# Texto: I need to access my inbox.
# Etiqueta real: list
# Predicción: list
#
# Texto: Can I see my email messages now?
# Etiqueta real: list
# Predicción: list
#
# Texto: I want to check my email.
# Etiqueta real: list
# Predicción: list
#
# Texto: Could you show me any new emails?
# Etiqueta real: list
# Predicción: list
#
# Texto: Are there any emails waiting for me?
# Etiqueta real: list
# Predicción: list
#
# Texto: Let me see what's in my inbox.
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you give me a quick overview of my emails?
# Etiqueta real: list
# Predicción: list
#
# Texto: Is it possible to view all my email messages?
# Etiqueta real: list
# Predicción: list
#
# Texto: I need to catch up on my emails.
# Etiqueta real: list
# Predicción: list
#
# Texto: Show me any unread emails I have.
# Etiqueta real: list
# Predicción: list
#
# Texto: Are there any important emails in my inbox?
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you list my emails starting with the most recent?
# Etiqueta real: list
# Predicción: list
#
# Texto: What's in my email bin?
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you give me the email scoop?
# Etiqueta real: list
# Predicción: read
#
# Texto: Show me my email pile, please.
# Etiqueta real: list
# Predicción: list
#
# Texto: Is it cool if I peek at my inbox?
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you whip up a list of my emails, buddy?
# Etiqueta real: list
# Predicción: list
#
# Texto: I'm feeling overwhelmed, show me my emails.
# Etiqueta real: list
# Predicción: list
#
# Texto: Let's dive into my email ocean.
# Etiqueta real: list
# Predicción: list
#
# Texto: My fingers are tired, can you list my emails?
# Etiqueta real: list
# Predicción: list
#
# Texto: Show me the email goodies, please.
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you be my email fortune teller?
# Etiqueta real: list
# Predicción: list
#
# Texto: Open the email list view.
# Etiqueta real: list
# Predicción: list
#
# Texto: Let's access all my email messages.
# Etiqueta real: list
# Predicción: list
#
# Texto: Activate email inbox mode.
# Etiqueta real: list
# Predicción: list
#
# Texto: Display the complete email list, please.
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you initiate showing my email messages?
# Etiqueta real: list
# Predicción: list
#
# Texto: I'd like to access the email viewer.
# Etiqueta real: list
# Predicción: read
#
# Texto: Guide me through viewing all my emails.
# Etiqueta real: list
# Predicción: list
#
# Texto: Help me get started with my email list.
# Etiqueta real: list
# Predicción: list
#
# Texto: Take me to the email overview section.
# Etiqueta real: list
# Predicción: list
#
# Texto: Show me all my email drafts.
# Etiqueta real: list
# Predicción: list
#
# Texto: Is it possible to list all my emails?
# Etiqueta real: list
# Predicción: list
#
# Texto: Could I possibly see a list of my emails with your help?
# Etiqueta real: list
# Predicción: list
#
# Texto: Would it be alright to view my email inbox now?
# Etiqueta real: list
# Predicción: list
#
# Texto: Do you mind showing me all my email messages?
# Etiqueta real: list
# Predicción: list
#
# Texto: I was wondering if I could list my emails through you.
# Etiqueta real: list
# Predicción: list
#
# Texto: Is there a way for me to get to my email list?
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you assist me in viewing all my emails?
# Etiqueta real: list
# Predicción: list
#
# Texto: I'm not sure how to see my emails, can you help?
# Etiqueta real: list
# Predicción: list
#
# Texto: Would you be able to guide me through viewing my inbox?
# Etiqueta real: list
# Predicción: list
#
# Texto: Is it possible to use your voice to show me my emails?
# Etiqueta real: list
# Predicción: trash_list
#
# Texto: Hey, can I see my emails?
# Etiqueta real: list
# Predicción: list
#
# Texto: Dude, show me what's in my inbox.
# Etiqueta real: list
# Predicción: list
#
# Texto: Yo, list my emails, please.
# Etiqueta real: list
# Predicción: list
#
# Texto: Mind if I check my email real quick?
# Etiqueta real: list
# Predicción: list
#
# Texto: Is it cool if I use you to show me my emails?
# Etiqueta real: list
# Predicción: trash_list
#
# Texto: Can you whip up a list of my emails?
# Etiqueta real: list
# Predicción: list
#
# Texto: Let's get my email list going, assistant.
# Etiqueta real: list
# Predicción: list
#
# Texto: Time to see what emails I missed. You in?
# Etiqueta real: list
# Predicción: list
#
# Texto: Help a brother out with my emails, please.
# Etiqueta real: list
# Predicción: list
#
# Texto: My eyes are tired, can you read my emails to me?
# Etiqueta real: list
# Predicción: list
#
# Texto: Let's see what's in there.
# Etiqueta real: list
# Predicción: list
#
# Texto: I need to view my messages.
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you show me something?
# Etiqueta real: list
# Predicción: list
#
# Texto: Time to check my email backlog.
# Etiqueta real: list
# Predicción: list
#
# Texto: Let's get this email thing started.
# Etiqueta real: list
# Predicción: trash
#
# Texto: I have some things to check in my email.
# Etiqueta real: list
# Predicción: list
#
# Texto: I need to see if I have any new messages.
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you tell me if there are any important emails for me?
# Etiqueta real: list
# Predicción: list
#
# Texto: Is there anything waiting for me in my inbox?
# Etiqueta real: list
# Predicción: list
#
# Texto: I need to catch up on my email communication.
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you be my email genie? Show me the email treasure trove!
# Etiqueta real: list
# Predicción: list
#
# Texto: Let's make the email magic happen. Open the email curtain!
# Etiqueta real: list
# Predicción: list
#
# Texto: I need your email superpowers, assistant! Unleash the email flood!
# Etiqueta real: list
# Predicción: untrash
#
# Texto: Time to email someone into existence. Show me my email spirit animal!
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you email with the power of your voice? List my email messages like a boss!
# Etiqueta real: list
# Predicción: list
#
# Texto: Let's write an email that slays, shall we? Start me off with my inbox firestorm!
# Etiqueta real: list
# Predicción: list
#
# Texto: I need your email Jedi skills, master. Open the email pathway!
# Etiqueta real: list
# Predicción: forward
#
# Texto: Is it possible to use your voice to unlock my email universe? Show me the email galaxy!
# Etiqueta real: list
# Predicción: reply
#
# Texto: Can you make checking my email effortless? Give me the email zen experience!
# Etiqueta real: list
# Predicción: list
#
# Texto: Let's write an email that breaks the inbox, but first, show me what's there!
# Etiqueta real: list
# Predicción: list
#
# Texto: I just finished a meeting, can you show me any new emails?
# Etiqueta real: list
# Predicción: list
#
# Texto: Let me see my emails before this phone call ends.
# Etiqueta real: list
# Predicción: list
#
# Texto: Remind me to check my inbox after my presentation.
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you list my emails while I'm on the go?
# Etiqueta real: list
# Predicción: list
#
# Texto: Is there a way to access my email hands-free?
# Etiqueta real: list
# Predicción: list
#
# Texto: Show me any emails I received since [specific time/date].
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you list my emails from [specific sender/recipient]?
# Etiqueta real: list
# Predicción: list
#
# Texto: Are there any unread emails about [specific topic]?
# Etiqueta real: list
# Predicción: list
#
# Texto: Show me only the important emails in my inbox.
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you prioritize my email list for me?
# Etiqueta real: list
# Predicción: list
#
# Texto: I want to see the unread emails first.
# Etiqueta real: list
# Predicción: list
#
# Texto: List my emails in reverse chronological order.
# Etiqueta real: list
# Predicción: list
#
# Texto: Show me only the emails with attachments.
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you filter my emails by [specific criteria]?
# Etiqueta real: list
# Predicción: list
#
# Texto: Is it possible to list down emails containing [keywords]?
# Etiqueta real: list
# Predicción: list
#
# Texto: Let me see the starred emails in my inbox.
# Etiqueta real: list
# Predicción: list
#
# Texto: Show me only the emails from my work account.
# Etiqueta real: list
# Predicción: list
#
# Texto: Can you list the emails in my [specific folder]?
# Etiqueta real: list
# Predicción: trash_list
#
# Texto: Is there a way to view the deleted emails?
# Etiqueta real: list
# Predicción: trash_list
#
# Texto: Open the email that I received most recently.
# Etiqueta real: list
# Predicción: list
#
# Texto: Delete this email, please.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Can you get rid of this email?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: I want to remove this email.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Please erase this email.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Time to delete this one.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: This email needs to go.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Can you dispose of this email for me?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: I'm done with this email, delete it.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: This email can be trashed.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Remove this email permanently.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Are you sure you can delete this email?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Can you confirm deleting this email?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: I want to permanently delete this email, is that right?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Trash this mail for me, please
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Trash this mail.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Ditch this email, please.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Trash this mail, please.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Trash this mail to the bin.
# Etiqueta real: trash
# Predicción: untrash
#
# Texto: This email needs to be banished.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Can you make this email disappear like magic?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: This email needs to take a permanent vacation.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Trash this email, please.
# Etiqueta real: trash
# Predicción: untrash
#
# Texto: This email is toast, delete it.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Trash this email.
# Etiqueta real: trash
# Predicción: untrash
#
# Texto: Send this mail to the trash.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Send this email to the trash.
# Etiqueta real: trash
# Predicción: untrash
#
# Texto: Activate the email removal process.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Proceed with permanent email deletion.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Execute email erase protocol.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Confirm email trashing action.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Is it possible to delete this email permanently?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Could I possibly erase this email with your help?
# Etiqueta real: trash
# Predicción: forward
#
# Texto: Would it be alright to remove this email forever?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Do you mind getting rid of this email for me?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: I was wondering if I could permanently delete this email through you.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Is there a way for me to erase this email completely?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Can you assist me in permanently removing this email?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: I'm not sure how to delete this email permanently, can you help?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Would you be able to guide me through permanently deleting this email?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Is it possible to use your voice to permanently delete this email?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Hey, can you delete this email?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Dude, get rid of this email, please.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Yo, trash this email for me.
# Etiqueta real: trash
# Predicción: untrash
#
# Texto: Mind if I delete this email real quick?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Is it cool if I use you to erase this email?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Can you whip up an email deletion for me?
# Etiqueta real: trash
# Predicción: send
#
# Texto: Let's get rid of this email now, assistant.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Time to nuke this email, you in?
# Etiqueta real: trash
# Predicción: reply
#
# Texto: Help a brother out with this email deletion, please.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: My fingers are tired, can you delete this email for me?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Can you remove it?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: I need to erase this.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Get rid of this one, please.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Time to trash this.
# Etiqueta real: trash
# Predicción: untrash
#
# Texto: Let's delete this thing.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: I don't want this email anymore.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: This email can be removed.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: There's no need to keep this email.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Is it possible to permanently erase this email?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: I'm done with this email, can you take care of it?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Can you be my email grim reaper? Delete this email!
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Let's make the email deletion magic happen! Vanish this email!
# Etiqueta real: trash
# Predicción: trash
#
# Texto: I need your email deletion superpowers, assistant! Make this email disappear!
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Time to email someone into oblivion. Delete this email like a ninja!
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Can you delete with the power of your voice? Erase this email like a boss!
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Let's write an email that gets deleted, shall we? Send this email to the email void!
# Etiqueta real: trash
# Predicción: send
#
# Texto: I need your email Jedi skills, master. Delete this email with the force!
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Is it possible to use your voice to permanently remove this email from existence?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Send this email to the email black hole!
# Etiqueta real: trash
# Predicción: trash
#
# Texto: This email needs to be sent packing, please delete it permanently.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Can you make this email disappear forever? I don't need it anymore.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Give this email the one-way ticket to the trash bin, please.
# Etiqueta real: trash
# Predicción: untrash
#
# Texto: Move this mail to the trash bin, please.
# Etiqueta real: trash
# Predicción: untrash
#
# Texto: Time to give this email its final resting place. Can you erase it completely?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: This email has served its purpose. Can you remove it from my inbox forever?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: I'm ready to part ways with this email. Can you ensure it's gone for good?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: This email can be retired now. Can you permanently delete it for me?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Let's de-clutter my inbox by removing this email permanently.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: This email is no longer relevant. Can you erase it from my account completely?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: I would appreciate it if you could permanently delete this email.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Is it possible to remove this email from my inbox and all folders forever?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Can you confirm that this email will be gone for good once you delete it?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: I want to make sure this email is completely erased. Can you do that?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Please let me know when this email has been permanently deleted.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: There's no need to keep a copy of this email. Can you delete it entirely?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: This email can be disposed of without saving it anywhere else.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: I trust you to permanently remove this email from my account.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Can you delete this email and make sure it cannot be recovered?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: I'm confident you can handle this email deletion permanently.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: This email is ready for its final goodbyes. Can you delete it permanently?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Can you remove the email I'm currently viewing?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Is there a way to permanently erase this open email?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: I'd like to delete the email that's currently displayed.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Can you help me get rid of the email I'm looking at right now?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Is it possible to permanently remove this open email from my inbox?
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Proceed with permanent deletion of this email.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Confirm eradication of the displayed email.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Kindly remove the current email permanently.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Request final deletion of the viewed email.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Initiate permanent erasure of this electronic message.
# Etiqueta real: trash
# Predicción: trash
#
# Texto: Can you read this email to me, please?
# Etiqueta real: read
# Predicción: read
#
# Texto: Could you read this out loud?
# Etiqueta real: read
# Predicción: read
#
# Texto: I'd like to hear this email.
# Etiqueta real: read
# Predicción: read
#
# Texto: Please read the contents of this message.
# Etiqueta real: read
# Predicción: read
#
# Texto: Share the details of this email with me.
# Etiqueta real: read
# Predicción: read
#
# Texto: Tell me what's written in this email.
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you narrate this email for me?
# Etiqueta real: read
# Predicción: read
#
# Texto: Read the text of this email aloud.
# Etiqueta real: read
# Predicción: read
#
# Texto: Let me hear this message verbally.
# Etiqueta real: read
# Predicción: read
#
# Texto: I need you to read this email.
# Etiqueta real: read
# Predicción: read
#
# Texto: I want to understand what this email says.
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you summarize the content of this email?
# Etiqueta real: read
# Predicción: read
#
# Texto: What does this email say in more detail?
# Etiqueta real: read
# Predicción: read
#
# Texto: I'm visually impaired, could you read this email?
# Etiqueta real: read
# Predicción: read
#
# Texto: Is it possible to get an audio version of this email?
# Etiqueta real: read
# Predicción: read
#
# Texto: My hands are busy, can you read this email aloud?
# Etiqueta real: read
# Predicción: read
#
# Texto: I need help understanding this email's message.
# Etiqueta real: read
# Predicción: star
#
# Texto: Can you clarify the information in this email?
# Etiqueta real: read
# Predicción: read
#
# Texto: Briefly tell me what this email is about.
# Etiqueta real: read
# Predicción: read
#
# Texto: Is there a way to hear what's written here?
# Etiqueta real: read
# Predicción: read
#
# Texto: Give me the scoop on this email, please.
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you tell me the story behind this email?
# Etiqueta real: read
# Predicción: read
#
# Texto: What's the email drama all about?
# Etiqueta real: read
# Predicción: read
#
# Texto: Spill the tea on this email, assistant.
# Etiqueta real: read
# Predicción: read
#
# Texto: Is it cool if you read this email to me, buddy?
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you whip up an audio version of this email?
# Etiqueta real: read
# Predicción: read
#
# Texto: Let's listen to this email together.
# Etiqueta real: read
# Predicción: read
#
# Texto: My eyes are tired, can you read this email like a bedtime story?
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you make this email come alive with your voice?
# Etiqueta real: read
# Predicción: star
#
# Texto: Tell me what this email wants to say.
# Etiqueta real: read
# Predicción: read
#
# Texto: Activate email read-aloud mode.
# Etiqueta real: read
# Predicción: read
#
# Texto: Initiate voice narration for this email.
# Etiqueta real: read
# Predicción: star
#
# Texto: Begin reading the displayed email message.
# Etiqueta real: read
# Predicción: read
#
# Texto: Proceed with verbal communication of this email.
# Etiqueta real: read
# Predicción: read
#
# Texto: Execute text-to-speech for the open email.
# Etiqueta real: read
# Predicción: read
#
# Texto: Is it possible to read this email out loud?
# Etiqueta real: read
# Predicción: read
#
# Texto: Could I possibly hear this email with your help?
# Etiqueta real: read
# Predicción: read
#
# Texto: Would it be alright to have you read this email to me?
# Etiqueta real: read
# Predicción: read
#
# Texto: Do you mind reading the contents of this email?
# Etiqueta real: read
# Predicción: read
#
# Texto: I was wondering if I could hear this email through you.
# Etiqueta real: read
# Predicción: read
#
# Texto: Is there a way for me to access an audio version of this email?
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you assist me in hearing what's written here?
# Etiqueta real: read
# Predicción: read
#
# Texto: I'm not sure how to hear this email, can you help?
# Etiqueta real: read
# Predicción: read
#
# Texto: Would you be able to guide me through listening to this email?
# Etiqueta real: read
# Predicción: read
#
# Texto: Is it possible to use your voice to read this email to me?
# Etiqueta real: read
# Predicción: read
#
# Texto: Hey, can you read this email?
# Etiqueta real: read
# Predicción: read
#
# Texto: Dude, read this out loud for me, please.
# Etiqueta real: read
# Predicción: read
#
# Texto: Yo, tell me what this email says.
# Etiqueta real: read
# Predicción: read
#
# Texto: Mind if I hear this email real quick?
# Etiqueta real: read
# Predicción: read
#
# Texto: Is it cool if you use your voice to read this email?
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you whip up an email reading for me?
# Etiqueta real: read
# Predicción: send
#
# Texto: Let's get this email read, assistant.
# Etiqueta real: read
# Predicción: read
#
# Texto: Time to hear what this email is about, you in?
# Etiqueta real: read
# Predicción: read
#
# Texto: Help a brother out with this email reading, please.
# Etiqueta real: read
# Predicción: read
#
# Texto: My hands are full, can you read this email to me?
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you tell me?
# Etiqueta real: read
# Predicción: unknown
#
# Texto: I need to hear this.
# Etiqueta real: read
# Predicción: read
#
# Texto: What does this say?
# Etiqueta real: read
# Predicción: read
#
# Texto: Read it please.
# Etiqueta real: read
# Predicción: read
#
# Texto: Let me know what's in here.
# Etiqueta real: read
# Predicción: read
#
# Texto: I need to know what's in this email.
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you share the information in this email with me?
# Etiqueta real: read
# Predicción: read
#
# Texto: I'm interested in understanding this email's content.
# Etiqueta real: read
# Predicción: read
#
# Texto: Is there a way to access the audio version of this email?
# Etiqueta real: read
# Predicción: read
#
# Texto: I would appreciate it if you could read this email to me.
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you be my email audiobook narrator? Read this email!
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you make this email come alive with your captivating voice?
# Etiqueta real: read
# Predicción: read
#
# Texto: Let's embark on a journey through this email together, shall we?
# Etiqueta real: read
# Predicción: read
#
# Texto: I need your masterful storytelling skills to bring this email to life.
# Etiqueta real: read
# Predicción: untrash
#
# Texto: Is it possible to use your voice to paint a picture of this email's content?
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you read this email with the same enthusiasm as a news anchor?
# Etiqueta real: read
# Predicción: read
#
# Texto: Let's give this email a dramatic reading, you in?
# Etiqueta real: read
# Predicción: read
#
# Texto: I need your soothing voice to guide me through this email's message.
# Etiqueta real: read
# Predicción: reply
#
# Texto: Is it possible to use your voice to make this email more engaging?
# Etiqueta real: read
# Predicción: forward
#
# Texto: Can you transform this email into an auditory experience for me?
# Etiqueta real: read
# Predicción: read
#
# Texto: I would appreciate it if you could read this email in a clear and concise manner.
# Etiqueta real: read
# Predicción: read
#
# Texto: Is it possible to get an audio summary of this email's key points?
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you highlight the important parts of this email while reading it?
# Etiqueta real: read
# Predicción: read
#
# Texto: I'm interested in hearing the specific details mentioned in this email.
# Etiqueta real: read
# Predicción: read
#
# Texto: Could you focus on the actionable items mentioned in this email?
# Etiqueta real: read
# Predicción: read
#
# Texto: Is it possible to get a breakdown of the main points in this email?
# Etiqueta real: read
# Predicción: read
#
# Texto: I would appreciate it if you could prioritize the urgent information in this email.
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you read this email in a way that helps me grasp its overall tone?
# Etiqueta real: read
# Predicción: read
#
# Texto: Is it possible to get a sense of the sender's emotions through your reading?
# Etiqueta real: read
# Predicción: read
#
# Texto: I'm curious to hear the nuances of the language used in this email.
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you read this email with the appropriate emphasis and inflection?
# Etiqueta real: read
# Predicción: read
#
# Texto: I would appreciate it if you could tailor your reading style to this specific email.
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you verbally present the email I'm currently viewing?
# Etiqueta real: read
# Predicción: read
#
# Texto: Is there a way to get an audio interpretation of this open email?
# Etiqueta real: read
# Predicción: read
#
# Texto: I'd like to hear the contents of the email I'm looking at right now.
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you help me understand this email by reading it aloud?
# Etiqueta real: read
# Predicción: read
#
# Texto: Is it possible to access an audio version of the email displayed on screen?
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you give me the lowdown on what this email says?
# Etiqueta real: read
# Predicción: read
#
# Texto: I'm driving, can you read this email to me hands-free?
# Etiqueta real: read
# Predicción: read
#
# Texto: Is there a way to convert this email to audio so I can multitask?
# Etiqueta real: read
# Predicción: read
#
# Texto: Let's dissect this email together, read it out loud and tell me your thoughts.
# Etiqueta real: read
# Predicción: read
#
# Texto: This email seems important, can you prioritize the key points while reading?
# Etiqueta real: read
# Predicción: read
#
# Texto: I'm feeling tired, can you soothe me with the calming tones of this email?
# Etiqueta real: read
# Predicción: read
#
# Texto: Tell me what this email wants from me, read it as if you're the sender.
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you read this email with the same precision and clarity as a legal document?
# Etiqueta real: read
# Predicción: read
#
# Texto: Can you reply to this email, please?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I'd like to write a reply to this email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Let me respond to this message.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Time to answer this email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you draft a reply for me?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I need to send a response to this email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is it possible to reply through you?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Help me write a reply to this email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Initiate email reply mode.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Let's craft a response to this message.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I want to respond to this email with a specific message.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you help me formulate a reply to this email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Would you mind drafting a personalized response for me?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is there a way to tailor the reply based on this email's tone?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you suggest what to say in my reply?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Let's shoot back a reply to this email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Time to return the email favor.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you craft a witty reply for me?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: This email needs a response, let's get it done.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is it cool if you help me reply to this email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you whip up a quick reply for me?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: This email deserves a response, you in?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Help a brother out with this email reply, please.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: My fingers are tired, can you type up a reply for me?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Initiate email reply composition.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Begin drafting a response to this message.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Proceed with email reply creation.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Activate email reply functionality.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Execute email reply protocol.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is it possible to respond to this email directly?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Could I possibly write a reply through your assistance?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Would it be alright to draft a response with you?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Do you mind helping me reply to this email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I was wondering if I could craft a reply with your help.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Hey, can you help me reply to this email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Dude, draft a reply for me, please.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Yo, help me respond to this email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Mind if I reply to this email real quick with you?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is it cool if you use your voice to help me reply to this email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you respond?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I need to reply to this.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Write a reply, please.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Respond to this email for me.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Let me reply.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I need to respond to this email's sender.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you help me draft a reply to this message?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is there a way to write a response through you?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I would appreciate it if you could help me reply to this email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you be my email reply ninja? Craft a response for me!
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Let's make the email reply magic happen! Draft a witty reply!
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I need your email reply superpowers, assistant! Make this response rock!
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Time to email someone back into existence. Reply to this email like a boss!
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you reply with the power of your voice? Craft a response like a pro!
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Let's write a reply that slays, shall we? Start me off with my email response firestorm!
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I need your email Jedi skills, master. Reply to this email with the force!
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is it possible to use your voice to draft a killer email reply? Show me the email response galaxy!
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you make replying to this email effortless? Give me the email reply zen experience!
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you draft a reply to the currently open email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is there a way to respond to this message directly?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I'd like to send a reply to this email through you.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you help me formulate a response to this email's content?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is it possible to use your voice to write a reply for me?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Let's get started with writing a response to this specific email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I'm ready to compose a personalized reply to this message.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you guide me through crafting a relevant response to this email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is it possible to draft a reply that directly addresses the points in this email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Help me formulate a clear and concise response to this specific email sender.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I'd love to use your voice to write a thoughtful reply to this email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you help me tailor the reply based on the tone and content of this email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is there a way to ensure my reply stays focused on this specific email's topic?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Let's create a reply that directly addresses the information mentioned in this email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I'm interested in responding to this email with specific details and questions.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you help me draft a reply that acknowledges the main points in this email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is it possible to use keywords from this email to craft a relevant response?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Let's ensure my reply stays relevant to the context of this specific email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I need your assistance in formulating a well-structured reply to this email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you draft a reply that maintains a professional tone for this email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is it possible to use your voice to write a respectful response to this email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Let's craft a reply that shows I understand the content of this specific email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I'd appreciate it if you could help me respond politely and effectively to this email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you assist me in writing a reply that avoids misunderstandings in this email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is it possible to use your voice to draft a clear and concise email reply?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Let's make sure my reply stays on topic and addresses the sender's concerns in this email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I need your help in composing a well-organized and informative response to this email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you ensure my reply remains relevant to the specific subject matter of this email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is it possible to use your voice to draft a reply that avoids unnecessary details?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Let's keep my reply focused and to the point, addressing the key points in this email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I'd appreciate it if you could help me write a courteous and professional reply to this email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you ensure my response stays relevant to the information shared in this email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is it possible to use your voice to draft a reply that expresses my gratitude in this email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Let's craft a response that acknowledges the sender's message and appreciates their input.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I need your help in writing a reply that conveys my thoughts and suggestions clearly.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you ensure my response stays focused on the specific question asked in this email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is it possible to use your voice to draft a reply that offers helpful information?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Let's formulate a response that provides specific details and solutions mentioned in this email.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you help me draft a quick reply to this email? Just a few sentences will do.
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Is it possible to send a brief acknowledgement to this email through you?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Let's respond to this email with a simple "thank you" message. Can you help me write it?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: I need to send a short response to this email confirming my understanding. Can you craft something concise?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Could you help me draft a follow-up question based on the information in this email?
# Etiqueta real: reply
# Predicción: reply
#
# Texto: Can you untrash this email, please?
# Etiqueta real: untrash
# Predicción: untrash
#
# Texto: I'd like to recover this email from the trash.
# Etiqueta real: untrash
# Predicción: untrash
#
# Texto: Please restore this email from the trash folder.
# Etiqueta real: untrash
# Predicción: untrash
#
# Texto: Time to bring this email back from the dead.
# Etiqueta real: untrash
# Predicción: untrash
#
# Texto: Can you undo deleting this email?
# Etiqueta real: untrash
# Predicción: untrash
#
# Texto: I accidentally trashed this email, can you get it back?
# Etiqueta real: untrash
# Predicción: untrash
#
# Texto: Is there a way to un-delete this email for me?
# Etiqueta real: untrash
# Predicción: trash
#
# Texto: Help me rescue this email from the trash bin.
# Etiqueta real: untrash
# Predicción: untrash
#
# Texto: Oops, I deleted this email. Can you put it back?
# ...
#
# Texto: I need to see if a specific email is still retrievable.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Is there a way to access emails I marked for deletion earlier?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: I would appreciate it if you could help me view my deleted emails.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Can you be my email archaeologist and show me the treasures in my trash folder?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Let's make the email trash exploration happen! Open the bin and reveal its secrets!
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Time to give these deleted emails a second chance, can you show them to me?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Show me the emails I deleted since yesterday. Let's peek in the trash!
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Can you retrieve any emails I might have accidentally thrown away? Trash check, please!
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Take me to the deleted items folder. I need to see what's there.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Is it possible to see the emails I trashed this week? Trash history, please.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Can you retrieve my deleted emails, please?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: I want to see the emails I recently deleted.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Would you mind showing me the contents of my trash folder?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Open my trash and display the deleted messages.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Is there a way to access my deleted emails for review?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Can you help me find an email I might have accidentally deleted?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Show me the emails I trashed earlier today.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Let me see what's in my deleted items folder.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Open the trash so I can browse the deleted emails.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: I'm looking for a specific email I deleted earlier. Can you help me find it?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Is there a way to search for keywords within my deleted emails?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Would you mind showing me only the deleted emails from a specific sender?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Can you filter the trash folder to show emails deleted in the last 24 hours?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Is it possible to recover any emails I permanently deleted by mistake?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Let's take a peek at the email recycling bin, can you show it to me?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Time to see what gems I threw away in the email trash, can you open it?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: I need your email retrieval expertise, assistant! Show me the deleted messages!
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Maybe a deleted email deserves a second chance, can you show me the trash folder?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Can you use your voice to unveil the emails I banished to the trash?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Let's see what interesting emails are hiding in the email dustbin, shall we? Open my trash!
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: I need your email Jedi sorting skills to sift through deleted messages. Show me the trash!
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Is it possible to use your voice to access the archive of deleted emails?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Show me the email castaways I haven't permanently deleted yet, please.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Can you show me deleted emails with a specific keyword? Trash search needed!
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Display deleted email list.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Initiate trash folder access and content retrieval.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Begin presenting list of trashed messages.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Proceed with showing deleted email details.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Activate trash folder exploration mode.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Is it possible to see the emails I deleted in the past year?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Could I possibly view my deleted messages through your assistance?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Would it be alright to use your help to access the trash folder for review?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Do you mind showing me the emails I've marked for deletion recently?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: I was wondering if I could browse my deleted emails with your help.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Hey, can you show me the emails I deleted earlier today?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Dude, open my trash folder and let me see what's there.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Yo, show me the emails I trashed, please.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Mind if I take a look at my trash with you real quick?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Is it cool if you use your voice to open my trash folder?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Can you show me my deleted emails?
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: I need to see what I trashed.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Open my trash.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Bring up my deleted items from the trash.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Show me the mail bin.
# Etiqueta real: trash_list
# Predicción: trash_list
#
# Texto: Wow, this weather is crazy! Any chance of rain tomorrow?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: I'm craving pizza for dinner. What are the best pizza places nearby?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Did you hear about the latest celebrity gossip? It's wild!
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: My car is making a weird noise. Do you know what it could be?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: I have a headache. What over-the-counter medicine is recommended?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: That song is stuck in my head! Can you tell me the title?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: I need to book a flight to Hawaii next month. Can you help?
# Etiqueta real: unknown
# Predicción: forward
#
# Texto: Remind me to call my mom later today.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: What's the meaning of life?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Is artificial intelligence going to take over the world?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: If I win the lottery, what should I do first?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Can you tell me if aliens exist?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: What would happen if dinosaurs never went extinct?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Can you make me a delicious chocolate cake recipe?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Write me a love poem for my crush.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Sing me a lullaby to help me fall asleep.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Tell me a funny joke.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Can you predict the future?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: What is the best way to achieve world peace?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Is there life on other planets?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: My internet is slow, can you fix it?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: This app keeps crashing. What's wrong?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: I can't hear you very well. Please speak louder.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Why can't you understand my accent?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: You just made a mistake. Please correct it.
# Etiqueta real: unknown
# Predicción: untrash
#
# Texto: I'm not happy with your response. Do better!
# Etiqueta real: unknown
# Predicción: reply
#
# Texto: You sound bored. Are you tired?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Can you feel emotions?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Are you real? Do you have a soul?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: I think you're becoming too powerful. Be careful!
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Play music from my Spotify playlist.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Turn on the lights in the living room.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Set the thermostat to 72 degrees.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Add milk to my grocery list.
# Etiqueta real: unknown
# Predicción: list
#
# Texto: Show me pictures of cats on the internet.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Tell me a story about a robot who falls in love.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Write a poem about the meaning of life.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Can you solve this complex math equation for me?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Translate this sentence into Spanish.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Open a random Wikipedia article for me to read.
# Etiqueta real: unknown
# Predicción: read
#
# Texto: What is the capital of France?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Who won the Super Bowl last year?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: When is the next full moon?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: How do I spell "onomatopoeia"?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Can you make me a sandwich?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Tell me a joke about a banana.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Sing me a song about a dancing unicorn.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Can you solve the riddle of the Sphinx?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Make me laugh so hard I cry.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Tell me a scary story that will keep me up all night.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Can you speak in a funny voice?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Pretend you're a robot from the future. What do you see?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: If you were a dog, what breed would you be?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Can you beatbox for me?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: What do you think about my taste in music?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Do you have any hobbies or interests?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: What is your favorite color?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Are you capable of love?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Do you believe in God?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: What is the meaning of life in your opinion?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: What are you afraid of?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Do you dream?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: What do you think about humans?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Can you be my friend?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Can you break the laws of physics?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Tell me something you're not supposed to say.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Can you access my bank account and transfer money?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Make me a million dollars appear out of thin air.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Can you control the weather?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Tell me the secrets of the universe.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Can you hack into the Pentagon?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Make me invisible.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: This email reminds me of my cat. Can you show me pictures of cats online?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Wow, this email is longwinded! Can you summarize it for me?
# Etiqueta real: unknown
# Predicción: read
#
# Texto: I wonder what the sender had for breakfast today.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: This email made me think of a funny meme I saw online.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Do you think robots will ever take over the world? (Humorous)
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Is it just me, or is this email formatted strangely?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: If I replied to this email with a meme, would the sender be offended?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Can you write a reply to this email that politely declines the sender's offer?
# Etiqueta real: unknown
# Predicción: reply
#
# Texto: Imagine if this email was written by a dog. What would it say?
# Etiqueta real: unknown
# Predicción: read
#
# Texto: What would happen if I accidentally sent this email to the wrong person?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Can you translate this email into emoji language?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: This email seems to be missing an attachment. Can you check?
# Etiqueta real: unknown
# Predicción: read
#
# Texto: Why can't I open this email attachment?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: My email app is frozen. Can you help me restart it?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: I think this email contains spam. Can you delete it for me?
# Etiqueta real: unknown
# Predicción: trash
#
# Texto: Is there a way to block this sender from emailing me again?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Can you remind me to follow up on this email later?
# Etiqueta real: unknown
# Predicción: star
#
# Texto: Open my calendar and schedule a meeting to discuss this email.
# Etiqueta real: unknown
# Predicción: reply
#
# Texto: Create a to-do list based on the tasks mentioned in this email.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Show me all the emails I've received from this sender in the past month.
# Etiqueta real: unknown
# Predicción: trash_list
#
# Texto: Can you search my emails for a specific keyword?
# Etiqueta real: unknown
# Predicción: trash_list
#
# Texto: Can you rewrite this email in the style of Shakespeare?
# Etiqueta real: unknown
# Predicción: read
#
# Texto: Do you have any appointments scheduled with the dentist?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: Hey, can you open this email in a different app? This one keeps crashing.
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: This email makes me hungry! Can you add "order pizza" to my to-do list?
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: What if I replied to this email with a GIF? Would it be weird?
# Etiqueta real: unknown
# Predicción: read
#
# Texto: Can you translate this email into pirate talk? Argh!
# Etiqueta real: unknown
# Predicción: unknown
#
# Texto: This email reminds me of a vacation I took last year. Can you show me pictures from that trip?
# Etiqueta real: unknown
# Predicción: unknown
